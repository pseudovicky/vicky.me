# %%
\documentclass[a4paper,11pt]{article}

%----------------------------------------------------------------------------------------
% PACKAGES
%----------------------------------------------------------------------------------------
\usepackage{url}
\usepackage{parskip}
\setlength{\parskip}{0pt}
\usepackage{color}
\usepackage{graphicx}
\usepackage[usenames,dvipsnames]{xcolor}
\usepackage[scale=0.95, top=1.25cm, bottom=1.25cm]{geometry}
\usepackage{fontspec} % Use fontspec to load system fonts
\setmainfont{EB Garamond} % Set the document font to Garamond
\usepackage{setspace} % Package for line spacing
\setstretch{1.05} % Increase line spacing by 10%
\usepackage{tabularx}
\usepackage{enumitem}
\newcolumntype{C}{>{\centering\arraybackslash}X}
\usepackage{supertabular}
\newlength{\fullcollw}
\setlength{\fullcollw}{0.47\textwidth}
\usepackage{titlesec}
\usepackage{multicol}
\usepackage{multirow}
\usepackage[style=authoryear,sorting=ynt, maxbibnames=2]{biblatex}
\usepackage[unicode, draft=false]{hyperref}
\definecolor{linkcolour}{rgb}{0,0.2,0.6}
\hypersetup{colorlinks,breaklinks,urlcolor=linkcolour,linkcolor=linkcolour}
\setlength\bibitemsep{1em}
\usepackage{fontawesome5}

%----------------------------------------------------------------------------------------
% CV LAYOUT
%----------------------------------------------------------------------------------------
\titleformat{\section}{\large\scshape\raggedright}{}{0em}{}[\titlerule]
\titlespacing{\section}{0pt}{3pt}{3pt}

\newenvironment{jobshort}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  }
  {
  }

\newenvironment{joblong}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  \begin{minipage}[t]{\linewidth}
  \begin{itemize}[nosep,after=\strut, leftmargin=1em, itemsep=0.5pt,label=\textbullet]
  }
  {
  \end{itemize}
  \end{minipage}
  }

%----------------------------------------------------------------------------------------
% BEGIN DOCUMENT
%----------------------------------------------------------------------------------------
\begin{document}

\pagestyle{empty}

%----------------------------------------------------------------------------------------
%	TITLE
%----------------------------------------------------------------------------------------

% \begin{tabularx}{\linewidth}{ @{}X X@{} }
% \huge{Your Name}\vspace{2pt} & \hfill \emoji{incoming-envelope} email@email.com \\
% \raisebox{-0.05\height}\faGithub\ username \ | \
% \raisebox{-0.00\height}\faLinkedin\ username \ | \ \raisebox{-0.05\height}\faGlobe \ mysite.com  & \hfill \emoji{calling} number
% \end{tabularx}

\begin{tabularx}{\linewidth}{@{} C @{}}
\Huge{Vicky Kumar} \\[7.5pt]
\href{https://github.com/pseudovicky}{\raisebox{-0.05\height}\faGithub\ pseudovicky} \ $|$ \ 
\href{https://linkedin.com/in/pseudovicky}{\raisebox{-0.05\height}\faLinkedin\ pseudovicky} \ $|$ \ 
\href{https://vickykumar.me}{\raisebox{-0.05\height}\faGlobe \ vickykumar.me} \ $|$ \ 
\href{mailto:sudovicky@gmail.com}{\raisebox{-0.05\height}\faEnvelope \ sudovicky@gmail.com} \ $|$ \ 
\href{tel:+917295818429}{\raisebox{-0.05\height}\faMobile \ +91 7295818429} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	SKILLS
%----------------------------------------------------------------------------------------
\section{Skills}
\begin{tabularx}{\linewidth}{@{}l X@{}}

Languages & \normalsize{Python, C/C++, Java, DSA, HTML, CSS, JavaScript, MySQL, ML, DL, NLP, Neural Networks, MLDLC } \\

Frameworks & \normalsize{React.js, Tailwind CSS, Bootstrap, Node.js, Express.js} \\

Libraries & \normalsize{NumPy, Pandas, Matplotlib, Seaborn, Scikit-learn, Folium, Keras, TensorFlow, NLTK, Plotly, OpenCV } \\

Tools / Platforms & \normalsize{MongoDB, MS SQL Server, IBM Cognos, IBM Cloud, Excel, Selenium, Canva, Figma, Power BI, Cisco Packet Tracer} \\

Soft Skills & \normalsize{Problem-Solving, Teamwork, Strategic Planning, Technical Writing, Information Synthesis, Attention to Detail} \\
\end{tabularx}

%----------------------------------------------------------------------------------------
%	Experience
%----------------------------------------------------------------------------------------

\section{Experience}
\begin{joblong}{\textbf{Hariyalikart (Startup)} – Web Developer}{Jan '24 – Jul '24}
    \item Built and launched the company’s primary website \href{https://hariyalikart.com/}{hariyalikart.com}, supporting their mission of delivering smart-agriculture IoT and AI solutions to improve water usage and crop health.
    \item Developed full-stack features using the \textbf{MERN stack (MongoDB, Express.js, React.js, Node.js)}, integrating REST APIs and creating a fully responsive, mobile-first user experience.
    \item Collaborated with the tech team to implement feature enhancements, including real-time IoT sensor dashboards and dynamic content modules, improving farmer engagement and platform scalability.
    \item Optimized website performance—reducing load time, improving SEO, and enhancing mobile responsiveness—while ensuring maintainable code structure and effective version control practices.
\end{joblong}


%----------------------------------------------------------------------------------------
%	Research and Publication
%----------------------------------------------------------------------------------------
\section*{Research \& Publications}
\begin{joblong}{\textbf{The Relationship Between Data and Information} \textbf{-} Correlation, Transformation and Discovery through Data Science}{Nov '25}
\item Examined supermarket datasets and survey responses to analyze how raw data transforms into meaningful information through correlation analysis, data integrity checks, and variable-interaction patterns.
\item Applied \textbf{Association Rule Mining} (Apriori/FP-Growth) to uncover hidden relationships and extract latent behavioral and operational insights from complex datasets.
\end{joblong}


%----------------------------------------------------------------------------------------
%	Project
%----------------------------------------------------------------------------------------

\section{Projects}
%	Project 1 
\begin{joblong}{\textbf{Old Car Price Prediction} — Python, Pandas, NumPy, Scikit-learn, AdaBoost, Web Scraping}{Aug '25}
\item Scraped real world car data from Quikr and Kaggle, performed cleaning, anomaly detection, and feature engineering using Adjusted R\textsuperscript{2}.
\item Built a Linear Regression model boosted with \textbf{AdaBoost}, improving accuracy and achieving an overall \textbf{R\textsuperscript{2} ≈ 0.92} with detailed error analysis. 
\end{joblong}

%	Project 2
\begin{joblong}{\textbf{Sorting Algorithm Visualizer} (\href{https://sort-visualiser-chi.vercel.app/}{Deployed on Vercel})}{May '25}
\item Built an interactive web tool to visualize major sorting algorithms in real time, enhancing understanding of time/space complexity.
\item Implemented nine algorithms with step-by-step animations and user controls for data size, randomness, and speed.
\item Designed a \textbf{Node.js + Express + Socket.IO} architecture for smooth execution streaming and a clean, responsive bar-graph UI.
\end{joblong}


\begin{joblong}{\textbf{Association Rule Mining for Retail Optimization} — Python, MLxtend, IBM Watson Studio, IBM Cloud}{Mar '25}
\item Built a market basket analysis system using \textbf{Apriori} and \textbf{FP-Growth} algorithms to find which products are frequently bought together.
\item Used \textbf{support, confidence, and lift} to create useful recommendations for product placement and combo offers in supermarkets.
\item Deployed the solution on \textbf{IBM Cloud} with Watson Studio for easy access and real-time insights to help improve sales decisions.
\end{joblong}


\begin{joblong}{\textbf{CheckInn} — MySQL, Node.js, Express, JavaScript, React \quad
\href{https://github.com/pseudovicky/CheckInn}{GitHub} \;|\;
\href{https://docs.google.com/document/d/13uZuB80_r-V9aIMEZW-nD5cQcaGiPV-5iy5fOFhbq6A/edit?usp=sharing}{Project Report}
}{Aug '24}
\item Built a full-stack hotel booking and management system using \textbf{MySQL}, Node.js, and JavaScript, designing optimized relational schemas, high-performance SQL queries, and secure booking workflows with responsive UI components.
\item Delivered dynamic stored procedures, triggers, and analytical SQL modules powering real-time operations and reporting.
\end{joblong}

\begin{joblong}{\textbf{Panic Buying Analysis During Early COVID-19} — Data Analysis, Google Mobility, Apple Mobility}{Aug '24}
\item Analyzed Google and Apple mobility datasets to track changes in essential shopping activity during the first COVID-19 wave and identify panic-buying behavior across regions.
\item Cleaned and visualized mobility trends to evaluate how lockdown announcements and movement restrictions influenced consumer stockpiling patterns.
\end{joblong}


%----------------------------------------------------------------------------------------
%	CERTIFICATIONS
%----------------------------------------------------------------------------------------

\section{Certificates}
\begin{jobshort}{\textbf{VLSI Design – MSME Professional Training} (\href{https://inleski.com/certificate.php?certificate=20250619IB7304617369}{INLESKI})}{Jun '25 -- Jul '25}
\end{jobshort}
\begin{jobshort}{\textbf{Responsive Web Design} (\href{https://www.freecodecamp.org/certification/fcc47b3390d-0c34-4d57-8948-2eac1209f8ea/responsive-web-design}{freeCodeCamp})}{Jul '25 -- Sep '25}
\end{jobshort}
\begin{jobshort}{\textbf{Machine Learning \& Data Visualization} (IBM)}{Oct '24 -- Jan '25}
\end{jobshort}
\begin{jobshort}{\textbf{Data Science Masters} (\href{https://pwskills.com/learn/certificate/7cb6d99b-da82-45dd-9784-06513263a44c/}{PW Skills})}{Jan '24 -- Dec '24}
\end{jobshort}
\begin{jobshort}{\textbf{MERN Stack Development} (\href{https://mycourse.app/qWomCXFiY9wBahWJA}{Apna College})}{Dec '22 -- Oct '23}
\end{jobshort}


%----------------------------------------------------------------------------------------
%	Activities \& Achievements
%----------------------------------------------------------------------------------------


\section{Activities \& Achievements}
\begin{itemize}[leftmargin=1em, itemsep=4pt]

    \item \textbf{Code-A-Haunt Hackathon (Coding Blocks, LPU):} 
    Participated in a high-intensity coding and development sprint focused on rapid problem-solving and teamwork. Built an \textbf{AI Therapist} Application using Python, Django, and Google AI Studio, integrating the trained model into the backend through API-based communication.

    \item \textbf{Responsive CSS Challenge — 21 Days Bootcamp:} 
    Completed 21 mini-projects in 21 days, strengthening expertise in responsive design, media queries, accessibility, and SEO-friendly UI development. Created modern, scalable, and production-ready CSS layouts.

    \item \textbf{AlumniConnect Application (MERN, Socket.io, APIs):} 
    Developed during the Code Strome 36-Hour Hackathon organized by \textbf{Microsoft Learn Student Ambassadors}, where our team was awarded \textbf{Runner-Up}. Designed a real-time mentorship platform enabling students and alumni to connect through live chat, appointment scheduling, and role-based dashboards.

\end{itemize}


%----------------------------------------------------------------------------------------
%	EDUCATION
%----------------------------------------------------------------------------------------


\section{Education}
\begin{tabularx}{\linewidth}{@{} X r @{}}

    \textbf{Lovely Professional University} & Phagwara, Punjab \\
    Master of Computer Application (Hons. in AI/ML), in collaboration with \textbf{IBM}; CGPA: 8.0 & Aug '24 – Present \\[1.5pt]

    \textbf{Indira Gandhi National Open University} & Patna, Bihar \\
    Bachelor of Computer Application; Percentage: 62\% & Jul '19 – Dec '23 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Intermediate (PCM); Percentage: 70\% & Mar '17 – Mar '19 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Matriculation; Percentage: 75\% & Mar '16 – Feb '17 \\

\end{tabularx}


\end{document}

# %%
\documentclass[a4paper,11pt]{article}

%----------------------------------------------------------------------------------------
% PACKAGES
%----------------------------------------------------------------------------------------
\usepackage{url}
\usepackage{parskip}
\setlength{\parskip}{0pt}
\usepackage{color}
\usepackage{graphicx}
\usepackage[usenames,dvipsnames]{xcolor}
\usepackage[scale=0.95, top=1.25cm, bottom=1.25cm]{geometry}
\usepackage{fontspec} % Use fontspec to load system fonts
\setmainfont{EB Garamond} % Set the document font to Garamond
\usepackage{setspace} % Package for line spacing
\setstretch{1.05} % Increase line spacing by 10%
\usepackage{tabularx}
\usepackage{enumitem}
\newcolumntype{C}{>{\centering\arraybackslash}X}
\usepackage{supertabular}
\newlength{\fullcollw}
\setlength{\fullcollw}{0.47\textwidth}
\usepackage{titlesec}
\usepackage{multicol}
\usepackage{multirow}
\usepackage[style=authoryear,sorting=ynt, maxbibnames=2]{biblatex}
\usepackage[unicode, draft=false]{hyperref}
\definecolor{linkcolour}{rgb}{0,0.2,0.6}
\hypersetup{colorlinks,breaklinks,urlcolor=linkcolour,linkcolor=linkcolour}
\setlength\bibitemsep{1em}
\usepackage{fontawesome5}

%----------------------------------------------------------------------------------------
% CV LAYOUT
%----------------------------------------------------------------------------------------
\titleformat{\section}{\large\scshape\raggedright}{}{0em}{}[\titlerule]
\titlespacing{\section}{0pt}{3pt}{3pt}

\newenvironment{jobshort}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  }
  {
  }

\newenvironment{joblong}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  \begin{minipage}[t]{\linewidth}
  \begin{itemize}[nosep,after=\strut, leftmargin=1em, itemsep=0.5pt,label=\textbullet]
  }
  {
  \end{itemize}
  \end{minipage}
  }

%----------------------------------------------------------------------------------------
% BEGIN DOCUMENT
%----------------------------------------------------------------------------------------
\begin{document}

\pagestyle{empty}

%----------------------------------------------------------------------------------------
%	TITLE
%----------------------------------------------------------------------------------------

% \begin{tabularx}{\linewidth}{ @{}X X@{} }
% \huge{Your Name}\vspace{2pt} & \hfill \emoji{incoming-envelope} email@email.com \\
% \raisebox{-0.05\height}\faGithub\ username \ | \
% \raisebox{-0.00\height}\faLinkedin\ username \ | \ \raisebox{-0.05\height}\faGlobe \ mysite.com  & \hfill \emoji{calling} number
% \end{tabularx}

\begin{tabularx}{\linewidth}{@{} C @{}}
\Huge{Vicky Kumar} \\[7.5pt]
\href{https://github.com/pseudovicky}{\raisebox{-0.05\height}\faGithub\ pseudovicky} \ $|$ \ 
\href{https://linkedin.com/in/pseudovicky}{\raisebox{-0.05\height}\faLinkedin\ pseudovicky} \ $|$ \ 
\href{https://vickykumar.me}{\raisebox{-0.05\height}\faGlobe \ vickykumar.me} \ $|$ \ 
\href{mailto:sudovicky@gmail.com}{\raisebox{-0.05\height}\faEnvelope \ sudovicky@gmail.com} \ $|$ \ 
\href{tel:+917295818429}{\raisebox{-0.05\height}\faMobile \ +91 7295818429} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	SKILLS
%----------------------------------------------------------------------------------------
\section{Skills}
\begin{tabularx}{\linewidth}{@{}l X@{}}

Languages & \normalsize{Python, C/C++, Java, DSA, HTML, CSS, JavaScript, MySQL, ML, DL, NLP, Neural Networks, MLDLC } \\

Frameworks & \normalsize{React.js, Tailwind CSS, Bootstrap, Node.js, Express.js} \\

Libraries & \normalsize{NumPy, Pandas, Matplotlib, Seaborn, Scikit-learn, Folium, Keras, TensorFlow, NLTK, Plotly, OpenCV } \\

Tools / Platforms & \normalsize{MongoDB, MS SQL Server, IBM Cognos, IBM Cloud, Excel, Selenium, Canva, Figma, Power BI, Cisco Packet Tracer} \\

Soft Skills & \normalsize{Problem-Solving, Teamwork, Strategic Planning, Technical Writing, Information Synthesis, Attention to Detail} \\
\end{tabularx}

%----------------------------------------------------------------------------------------
%	Experience
%----------------------------------------------------------------------------------------

\section{Experience}
\begin{joblong}{\textbf{Hariyalikart (Startup)} – Web Developer}{Jan '24 – Jul '24}
    \item Built and launched the company’s primary website \href{https://hariyalikart.com/}{hariyalikart.com}, supporting their mission of delivering smart-agriculture IoT and AI solutions to improve water usage and crop health.
    \item Developed full-stack features using the \textbf{MERN stack (MongoDB, Express.js, React.js, Node.js)}, integrating REST APIs and creating a fully responsive, mobile-first user experience.
    \item Collaborated with the tech team to implement feature enhancements, including real-time IoT sensor dashboards and dynamic content modules, improving farmer engagement and platform scalability.
    \item Optimized website performance—reducing load time, improving SEO, and enhancing mobile responsiveness—while ensuring maintainable code structure and effective version control practices.
\end{joblong}


%----------------------------------------------------------------------------------------
%	Research and Publicatio
%----------------------------------------------------------------------------------------
\section*{Research Work}
\begin{joblong}{\textbf{The Relationship Between Data and Information} \textbf{-} Correlation, Transformation and Discovery through Data Science}{Nov '25}
\item Examined supermarket datasets and survey responses to analyze how raw data transforms into meaningful information through correlation analysis, data integrity checks, and variable-interaction patterns.
\item Applied \textbf{Association Rule Mining} (Apriori/FP-Growth) to uncover hidden relationships and extract latent behavioral and operational insights from complex datasets.
\end{joblong}


%----------------------------------------------------------------------------------------
%	Project
%----------------------------------------------------------------------------------------

\section{Projects}
%	Project 1 
\begin{joblong}{\textbf{Old Car Price Prediction} — Python, Pandas, NumPy, Scikit-learn, AdaBoost, Web Scraping}{Aug '25}
\item Scraped real world car data from Quikr and Kaggle, performed cleaning, anomaly detection, and feature engineering using Adjusted R\textsuperscript{2}.
\item Built a Linear Regression model boosted with \textbf{AdaBoost}, improving accuracy and achieving an overall \textbf{R\textsuperscript{2} ≈ 0.92} with detailed error analysis. 
\end{joblong}

%	Project 2
\begin{joblong}{\textbf{Sorting Algorithm Visualizer} (\href{https://sort-visualiser-chi.vercel.app/}{Deployed on Vercel})}{May '25}
\item Built an interactive web tool to visualize major sorting algorithms in real time, enhancing understanding of time/space complexity.
\item Implemented nine algorithms with step-by-step animations and user controls for data size, randomness, and speed.
\item Designed a \textbf{Node.js + Express + Socket.IO} architecture for smooth execution streaming and a clean, responsive bar-graph UI.
\end{joblong}


\begin{joblong}{\textbf{Association Rule Mining for Retail Optimization} — Python, MLxtend, IBM Watson Studio, IBM Cloud}{Mar '25}
\item Built a market basket analysis system using \textbf{Apriori} and \textbf{FP-Growth} algorithms to find which products are frequently bought together.
\item Used \textbf{support, confidence, and lift} to create useful recommendations for product placement and combo offers in supermarkets.
\item Deployed the solution on \textbf{IBM Cloud} with Watson Studio for easy access and real-time insights to help improve sales decisions.
\end{joblong}


\begin{joblong}{\textbf{CheckInn} — MySQL, Node.js, Express, JavaScript, React \quad
\href{https://github.com/pseudovicky/CheckInn}{GitHub} \;|\;
\href{https://docs.google.com/document/d/13uZuB80_r-V9aIMEZW-nD5cQcaGiPV-5iy5fOFhbq6A/edit?usp=sharing}{Project Report}
}{Aug '24}
\item Built a full-stack hotel booking and management system using \textbf{MySQL}, Node.js, and JavaScript, designing optimized relational schemas, high-performance SQL queries, and secure booking workflows with responsive UI components.
\item Delivered dynamic stored procedures, triggers, and analytical SQL modules powering real-time operations and reporting.
\end{joblong}

\begin{joblong}{\textbf{Panic Buying Analysis During Early COVID-19} — Data Analysis, Google Mobility, Apple Mobility}{Aug '24}
\item Analyzed Google and Apple mobility datasets to track changes in essential shopping activity during the first COVID-19 wave and identify panic-buying behavior across regions.
\item Cleaned and visualized mobility trends to evaluate how lockdown announcements and movement restrictions influenced consumer stockpiling patterns.
\end{joblong}


%----------------------------------------------------------------------------------------
%	CERTIFICATIONS
%----------------------------------------------------------------------------------------

\section{Certificates}
\begin{jobshort}{\textbf{VLSI Design – MSME Professional Training} (\href{https://inleski.com/certificate.php?certificate=20250619IB7304617369}{INLESKI})}{Jun '25 -- Jul '25}
\end{jobshort}
\begin{jobshort}{\textbf{Responsive Web Design} (\href{https://www.freecodecamp.org/certification/fcc47b3390d-0c34-4d57-8948-2eac1209f8ea/responsive-web-design}{freeCodeCamp})}{Jul '25 -- Sep '25}
\end{jobshort}
\begin{jobshort}{\textbf{Machine Learning \& Data Visualization} (IBM)}{Oct '24 -- Jan '25}
\end{jobshort}
\begin{jobshort}{\textbf{Data Science Masters} (\href{https://pwskills.com/learn/certificate/7cb6d99b-da82-45dd-9784-06513263a44c/}{PW Skills})}{Jan '24 -- Dec '24}
\end{jobshort}
\begin{jobshort}{\textbf{MERN Stack Development} (\href{https://mycourse.app/qWomCXFiY9wBahWJA}{Apna College})}{Dec '22 -- Oct '23}
\end{jobshort}


%----------------------------------------------------------------------------------------
%	Activities \& Achievements
%----------------------------------------------------------------------------------------


\section{Activities \& Achievements}
\begin{itemize}[leftmargin=1em, itemsep=4pt]

    \item \textbf{Code-A-Haunt Hackathon (Coding Blocks, LPU):} 
    Participated in a high-intensity coding and development sprint focused on rapid problem-solving and teamwork. Built an \textbf{AI Therapist} Application using Python, Django, and Google AI Studio, integrating the trained model into the backend through API-based communication.

    \item \textbf{Responsive CSS Challenge — 21 Days Bootcamp:} 
    Completed 21 mini-projects in 21 days, strengthening expertise in responsive design, media queries, accessibility, and SEO-friendly UI development. Created modern, scalable, and production-ready CSS layouts.

    \item \textbf{AlumniConnect Application (MERN, Socket.io, APIs):} 
    Developed during the Code Strome 36-Hour Hackathon organized by \textbf{Microsoft Learn Student Ambassadors}, where our team was awarded \textbf{Runner-Up}. Designed a real-time mentorship platform enabling students and alumni to connect through live chat, appointment scheduling, and role-based dashboards.

\end{itemize}


%----------------------------------------------------------------------------------------
%	EDUCATION
%----------------------------------------------------------------------------------------


\section{Education}
\begin{tabularx}{\linewidth}{@{} X r @{}}

    \textbf{Lovely Professional University} & Phagwara, Punjab \\
    Master of Computer Application (Hons. in AI/ML), in collaboration with \textbf{IBM}; CGPA: 8.0 & Aug '24 – Present \\[1.5pt]

    \textbf{Indira Gandhi National Open University} & Patna, Bihar \\
    Bachelor of Computer Application; Percentage: 62\% & Jul '19 – Dec '23 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Intermediate (PCM); Percentage: 70\% & Mar '17 – Mar '19 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Matriculation; Percentage: 75\% & Mar '16 – Feb '17 \\

\end{tabularx}


\end{document}

# %%
\documentclass[a4paper,11pt]{article}

%----------------------------------------------------------------------------------------
% PACKAGES
%----------------------------------------------------------------------------------------
\usepackage{url}
\usepackage{parskip}
\setlength{\parskip}{0pt}
\usepackage{color}
\usepackage{graphicx}
\usepackage[usenames,dvipsnames]{xcolor}
\usepackage[scale=0.95, top=1.25cm, bottom=1.25cm]{geometry}
\usepackage{fontspec} % Use fontspec to load system fonts
\setmainfont{EB Garamond} % Set the document font to Garamond
\usepackage{setspace} % Package for line spacing
\setstretch{1.05} % Increase line spacing by 10%
\usepackage{tabularx}
\usepackage{enumitem}
\newcolumntype{C}{>{\centering\arraybackslash}X}
\usepackage{supertabular}
\newlength{\fullcollw}
\setlength{\fullcollw}{0.47\textwidth}
\usepackage{titlesec}
\usepackage{multicol}
\usepackage{multirow}
\usepackage[style=authoryear,sorting=ynt, maxbibnames=2]{biblatex}
\usepackage[unicode, draft=false]{hyperref}
\definecolor{linkcolour}{rgb}{0,0.2,0.6}
\hypersetup{colorlinks,breaklinks,urlcolor=linkcolour,linkcolor=linkcolour}
\setlength\bibitemsep{1em}
\usepackage{fontawesome5}

%----------------------------------------------------------------------------------------
% CV LAYOUT
%----------------------------------------------------------------------------------------
\titleformat{\section}{\large\scshape\raggedright}{}{0em}{}[\titlerule]
\titlespacing{\section}{0pt}{3pt}{3pt}

\newenvironment{jobshort}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  }
  {
  }

\newenvironment{joblong}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  \begin{minipage}[t]{\linewidth}
  \begin{itemize}[nosep,after=\strut, leftmargin=1em, itemsep=0.5pt,label=\textbullet]
  }
  {
  \end{itemize}
  \end{minipage}
  }

%----------------------------------------------------------------------------------------
% BEGIN DOCUMENT
%----------------------------------------------------------------------------------------
\begin{document}

\pagestyle{empty}

%----------------------------------------------------------------------------------------
%	TITLE
%----------------------------------------------------------------------------------------

% \begin{tabularx}{\linewidth}{ @{}X X@{} }
% \huge{Your Name}\vspace{2pt} & \hfill \emoji{incoming-envelope} email@email.com \\
% \raisebox{-0.05\height}\faGithub\ username \ | \
% \raisebox{-0.00\height}\faLinkedin\ username \ | \ \raisebox{-0.05\height}\faGlobe \ mysite.com  & \hfill \emoji{calling} number
% \end{tabularx}

\begin{tabularx}{\linewidth}{@{} C @{}}
\Huge{Vicky Kumar} \\[7.5pt]
\href{https://github.com/pseudovicky}{\raisebox{-0.05\height}\faGithub\ pseudovicky} \ $|$ \ 
\href{https://linkedin.com/in/pseudovicky}{\raisebox{-0.05\height}\faLinkedin\ pseudovicky} \ $|$ \ 
\href{https://vickykumar.me}{\raisebox{-0.05\height}\faGlobe \ vickykumar.me} \ $|$ \ 
\href{mailto:sudovicky@gmail.com}{\raisebox{-0.05\height}\faEnvelope \ sudovicky@gmail.com} \ $|$ \ 
\href{tel:+917295818429}{\raisebox{-0.05\height}\faMobile \ +91 7295818429} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	SKILLS
%----------------------------------------------------------------------------------------
\section{Skills}
\begin{tabularx}{\linewidth}{@{}l X@{}}

Languages & \normalsize{Python, C/C++, Java, DSA, HTML, CSS, JavaScript, MySQL, ML, DL, NLP, Neural Networks, MLDLC } \\

Frameworks & \normalsize{React.js, Tailwind CSS, Bootstrap, Node.js, Express.js} \\

Libraries & \normalsize{NumPy, Pandas, Matplotlib, Seaborn, Scikit-learn, Folium, Keras, TensorFlow, NLTK, Plotly, OpenCV } \\

Tools / Platforms & \normalsize{MongoDB, MS SQL Server, IBM Cognos, IBM Cloud, Excel, Selenium, Canva, Figma, Power BI, Cisco Packet Tracer} \\

Soft Skills & \normalsize{Problem-Solving, Teamwork, Strategic Planning, Technical Writing, Information Synthesis, Attention to Detail} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	Research and Publicatio
%----------------------------------------------------------------------------------------
\section*{Research Work}
\begin{joblong}{\textbf{The Relationship Between Data and Information} \textbf{-} Correlation, Transformation and Discovery through Data Science}{Nov '25}
\item Examined supermarket datasets and survey responses to analyze how raw data transforms into meaningful information through correlation analysis, data integrity checks, and variable-interaction patterns.
\item Applied \textbf{Association Rule Mining} (Apriori/FP-Growth) to uncover hidden relationships and extract latent behavioral and operational insights from complex datasets.
\end{joblong}


%----------------------------------------------------------------------------------------
%	Project
%----------------------------------------------------------------------------------------

\section{Projects}
%	Project 1 
\begin{joblong}{\textbf{Old Car Price Prediction} — Python, Pandas, NumPy, Scikit-learn, AdaBoost, Web Scraping}{Aug '25}
\item Scraped real world car data from Quikr and Kaggle, performed cleaning, anomaly detection, and feature engineering using Adjusted R\textsuperscript{2}.
\item Built a Linear Regression model boosted with \textbf{AdaBoost}, improving accuracy and achieving an overall \textbf{R\textsuperscript{2} ≈ 0.92} with detailed error analysis. 
\end{joblong}

%	Project 2
\begin{joblong}{\textbf{Sorting Algorithm Visualizer} (\href{https://sort-visualiser-chi.vercel.app/}{Deployed on Vercel})}{May '25}
\item Built an interactive web tool to visualize major sorting algorithms in real time, enhancing understanding of time/space complexity.
\item Implemented nine algorithms with step-by-step animations and user controls for data size, randomness, and speed.
\item Designed a \textbf{Node.js + Express + Socket.IO} architecture for smooth execution streaming and a clean, responsive bar-graph UI.
\end{joblong}


\begin{joblong}{\textbf{Association Rule Mining for Retail Optimization} — Python, MLxtend, IBM Watson Studio, IBM Cloud}{Mar '25}
\item Built a market basket analysis system using \textbf{Apriori} and \textbf{FP-Growth} algorithms to find which products are frequently bought together.
\item Used \textbf{support, confidence, and lift} to create useful recommendations for product placement and combo offers in supermarkets.
\item Deployed the solution on \textbf{IBM Cloud} with Watson Studio for easy access and real-time insights to help improve sales decisions.
\end{joblong}


\begin{joblong}{\textbf{CheckInn} — MySQL, Node.js, Express, JavaScript, React \quad
\href{https://github.com/pseudovicky/CheckInn}{GitHub} \;|\;
\href{https://docs.google.com/document/d/13uZuB80_r-V9aIMEZW-nD5cQcaGiPV-5iy5fOFhbq6A/edit?usp=sharing}{Project Report}
}{Aug '24}
\item Built a full-stack hotel booking and management system using \textbf{MySQL}, Node.js, and JavaScript, designing optimized relational schemas, high-performance SQL queries, and secure booking workflows with responsive UI components.
\item Delivered dynamic stored procedures, triggers, and analytical SQL modules powering real-time operations and reporting.
\end{joblong}

\begin{joblong}{\textbf{Panic Buying Analysis During Early COVID-19} — Data Analysis, Google Mobility, Apple Mobility}{Aug '24}
\item Analyzed Google and Apple mobility datasets to track changes in essential shopping activity during the first COVID-19 wave and identify panic-buying behavior across regions.
\item Cleaned and visualized mobility trends to evaluate how lockdown announcements and movement restrictions influenced consumer stockpiling patterns.
\end{joblong}


%----------------------------------------------------------------------------------------
%	CERTIFICATIONS
%----------------------------------------------------------------------------------------

\section{Certificates}
\begin{jobshort}{\textbf{VLSI Design – MSME Professional Training} (\href{https://inleski.com/certificate.php?certificate=20250619IB7304617369}{INLESKI})}{Jun '25 -- Jul '25}
\end{jobshort}
\begin{jobshort}{\textbf{Responsive Web Design} (\href{https://www.freecodecamp.org/certification/fcc47b3390d-0c34-4d57-8948-2eac1209f8ea/responsive-web-design}{freeCodeCamp})}{Jul '25 -- Sep '25}
\end{jobshort}
\begin{jobshort}{\textbf{Machine Learning \& Data Visualization} (IBM)}{Oct '24 -- Jan '25}
\end{jobshort}
\begin{jobshort}{\textbf{Data Science Masters} (\href{https://pwskills.com/learn/certificate/7cb6d99b-da82-45dd-9784-06513263a44c/}{PW Skills})}{Jan '24 -- Dec '24}
\end{jobshort}
\begin{jobshort}{\textbf{MERN Stack Development} (\href{https://mycourse.app/qWomCXFiY9wBahWJA}{Apna College})}{Dec '22 -- Oct '23}
\end{jobshort}


%----------------------------------------------------------------------------------------
%	Activities \& Achievements
%----------------------------------------------------------------------------------------


\section{Activities \& Achievements}
\begin{itemize}[leftmargin=1em, itemsep=4pt]

    \item \textbf{Code-A-Haunt Hackathon (Coding Blocks, LPU):} 
    Participated in a high-intensity coding and development sprint focused on rapid problem-solving and teamwork. Built an \textbf{AI Therapist} Application using Python, Django, and Google AI Studio, integrating the trained model into the backend through API-based communication.

    \item \textbf{Responsive CSS Challenge — 21 Days Bootcamp:} 
    Completed 21 mini-projects in 21 days, strengthening expertise in responsive design, media queries, accessibility, and SEO-friendly UI development. Created modern, scalable, and production-ready CSS layouts.

    \item \textbf{AlumniConnect Application (MERN, Socket.io, APIs):} 
    Developed during the Code Strome 36-Hour Hackathon organized by \textbf{Microsoft Learn Student Ambassadors}, where our team was awarded \textbf{Runner-Up}. Designed a real-time mentorship platform enabling students and alumni to connect through live chat, appointment scheduling, and role-based dashboards.

\end{itemize}

%----------------------------------------------------------------------------------------
%	EDUCATION
%----------------------------------------------------------------------------------------

\section{Education}
\begin{tabularx}{\linewidth}{@{} X r @{}}

    \textbf{Lovely Professional University} & Phagwara, Punjab \\
    Master of Computer Application (Hons. in AI/ML), in collaboration with \textbf{IBM}; CGPA: 8.0 & Aug '24 – Present \\[1.5pt]

    \textbf{Indira Gandhi National Open University} & Patna, Bihar \\
    Bachelor of Computer Application; Percentage: 62\% & Jul '19 – Dec '23 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Intermediate (PCM); Percentage: 70\% & Mar '17 – Mar '19 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Matriculation; Percentage: 75\% & Mar '16 – Feb '17 \\

\end{tabularx}

\end{document}

# %%
\documentclass[a4paper,11pt]{article}

%----------------------------------------------------------------------------------------
% PACKAGES
%----------------------------------------------------------------------------------------
\usepackage{url}
\usepackage{parskip}
\setlength{\parskip}{0pt}
\usepackage{color}
\usepackage{graphicx}
\usepackage[usenames,dvipsnames]{xcolor}
\usepackage[scale=0.95, top=1.25cm, bottom=1.25cm]{geometry}
\usepackage{fontspec} % Use fontspec to load system fonts
\setmainfont{EB Garamond} % Set the document font to Garamond
\usepackage{setspace} % Package for line spacing
\setstretch{1.05} % Increase line spacing by 10%
\usepackage{tabularx}
\usepackage{enumitem}
\newcolumntype{C}{>{\centering\arraybackslash}X}
\usepackage{supertabular}
\newlength{\fullcollw}
\setlength{\fullcollw}{0.47\textwidth}
\usepackage{titlesec}
\usepackage{multicol}
\usepackage{multirow}
\usepackage[style=authoryear,sorting=ynt, maxbibnames=2]{biblatex}
\usepackage[unicode, draft=false]{hyperref}
\definecolor{linkcolour}{rgb}{0,0.2,0.6}
\hypersetup{colorlinks,breaklinks,urlcolor=linkcolour,linkcolor=linkcolour}
\setlength\bibitemsep{1em}
\usepackage{fontawesome5}

%----------------------------------------------------------------------------------------
% CV LAYOUT
%----------------------------------------------------------------------------------------
\titleformat{\section}{\large\scshape\raggedright}{}{0em}{}[\titlerule]
\titlespacing{\section}{0pt}{3pt}{3pt}

\newenvironment{jobshort}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  }
  {
  }

\newenvironment{joblong}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  \begin{minipage}[t]{\linewidth}
  \begin{itemize}[nosep,after=\strut, leftmargin=1em, itemsep=0.5pt,label=\textbullet]
  }
  {
  \end{itemize}
  \end{minipage}
  }

%----------------------------------------------------------------------------------------
% BEGIN DOCUMENT
%----------------------------------------------------------------------------------------
\begin{document}

\pagestyle{empty}

%----------------------------------------------------------------------------------------
%	TITLE
%----------------------------------------------------------------------------------------

% \begin{tabularx}{\linewidth}{ @{}X X@{} }
% \huge{Your Name}\vspace{2pt} & \hfill \emoji{incoming-envelope} email@email.com \\
% \raisebox{-0.05\height}\faGithub\ username \ | \
% \raisebox{-0.00\height}\faLinkedin\ username \ | \ \raisebox{-0.05\height}\faGlobe \ mysite.com  & \hfill \emoji{calling} number
% \end{tabularx}

\begin{tabularx}{\linewidth}{@{} C @{}}
\Huge{Vicky Kumar} \\[7.5pt]
\href{https://github.com/pseudovicky}{\raisebox{-0.05\height}\faGithub\ pseudovicky} \ $|$ \ 
\href{https://linkedin.com/in/pseudovicky}{\raisebox{-0.05\height}\faLinkedin\ pseudovicky} \ $|$ \ 
\href{https://vickykumar.me}{\raisebox{-0.05\height}\faGlobe \ vickykumar.me} \ $|$ \ 
\href{mailto:sudovicky@gmail.com}{\raisebox{-0.05\height}\faEnvelope \ sudovicky@gmail.com} \ $|$ \ 
\href{tel:+917295818429}{\raisebox{-0.05\height}\faMobile \ +91 7295818429} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	SKILLS
%----------------------------------------------------------------------------------------
\section{Skills}
\begin{tabularx}{\linewidth}{@{}l X@{}}

Languages & \normalsize{Python, C/C++, Java, DSA, HTML, CSS, JavaScript, MySQL, ML, DL, NLP, Neural Networks, MLDLC } \\

Frameworks & \normalsize{React.js, Tailwind CSS, Bootstrap, Node.js, Express.js} \\

Libraries & \normalsize{NumPy, Pandas, Matplotlib, Seaborn, Scikit-learn, Folium, Keras, TensorFlow, NLTK, Plotly, OpenCV } \\

Tools / Platforms & \normalsize{MongoDB, MS SQL Server, IBM Cognos, IBM Cloud, Excel, Selenium, Canva, Figma, Power BI, Cisco Packet Tracer} \\

Soft Skills & \normalsize{Problem-Solving, Teamwork, Strategic Planning, Technical Writing, Information Synthesis, Attention to Detail} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	Project
%----------------------------------------------------------------------------------------

\section{Projects}
%	Project 1 
\begin{joblong}{\textbf{Old Car Price Prediction} — Python, Pandas, NumPy, Scikit-learn, AdaBoost, Web Scraping}{Aug '25}
\item Scraped real world car data from Quikr and Kaggle, performed cleaning, anomaly detection, and feature engineering using Adjusted R\textsuperscript{2}.
\item Built a Linear Regression model boosted with \textbf{AdaBoost}, improving accuracy and achieving an overall \textbf{R\textsuperscript{2} ≈ 0.92} with detailed error analysis. 
\end{joblong}

%	Project 2
\begin{joblong}{\textbf{Sorting Algorithm Visualizer} (\href{https://sort-visualiser-chi.vercel.app/}{Deployed on Vercel})}{May '25}
\item Built an interactive web tool to visualize major sorting algorithms in real time, enhancing understanding of time/space complexity.
\item Implemented nine algorithms with step-by-step animations and user controls for data size, randomness, and speed.
\item Designed a \textbf{Node.js + Express + Socket.IO} architecture for smooth execution streaming and a clean, responsive bar-graph UI.
\end{joblong}


\begin{joblong}{\textbf{Association Rule Mining for Retail Optimization} — Python, MLxtend, IBM Watson Studio, IBM Cloud}{Mar '25}
\item Built a market basket analysis system using \textbf{Apriori} and \textbf{FP-Growth} algorithms to find which products are frequently bought together.
\item Used \textbf{support, confidence, and lift} to create useful recommendations for product placement and combo offers in supermarkets.
\item Deployed the solution on \textbf{IBM Cloud} with Watson Studio for easy access and real-time insights to help improve sales decisions.
\end{joblong}


\begin{joblong}{\textbf{CheckInn} — MySQL, Node.js, Express, JavaScript, React \quad
\href{https://github.com/pseudovicky/CheckInn}{GitHub} \;|\;
\href{https://docs.google.com/document/d/13uZuB80_r-V9aIMEZW-nD5cQcaGiPV-5iy5fOFhbq6A/edit?usp=sharing}{Project Report}
}{Aug '24}
\item Built a full-stack hotel booking and management system using \textbf{MySQL}, Node.js, and JavaScript, designing optimized relational schemas, high-performance SQL queries, and secure booking workflows with responsive UI components.
\item Delivered dynamic stored procedures, triggers, and analytical SQL modules powering real-time operations and reporting.
\end{joblong}

\begin{joblong}{\textbf{Panic Buying Analysis During Early COVID-19} — Data Analysis, Google Mobility, Apple Mobility}{Aug '24}
\item Analyzed Google and Apple mobility datasets to track changes in essential shopping activity during the first COVID-19 wave and identify panic-buying behavior across regions.
\item Cleaned and visualized mobility trends to evaluate how lockdown announcements and movement restrictions influenced consumer stockpiling patterns.
\end{joblong}


%----------------------------------------------------------------------------------------
%	CERTIFICATIONS
%----------------------------------------------------------------------------------------

\section{Certificates}
\begin{jobshort}{\textbf{VLSI Design – MSME Professional Training} (\href{https://inleski.com/certificate.php?certificate=20250619IB7304617369}{INLESKI})}{Jun '25 -- Jul '25}
\end{jobshort}
\begin{jobshort}{\textbf{Responsive Web Design} (\href{https://www.freecodecamp.org/certification/fcc47b3390d-0c34-4d57-8948-2eac1209f8ea/responsive-web-design}{freeCodeCamp})}{Jul '25 -- Sep '25}
\end{jobshort}
\begin{jobshort}{\textbf{Machine Learning \& Data Visualization} (IBM)}{Oct '24 -- Jan '25}
\end{jobshort}
\begin{jobshort}{\textbf{Data Science Masters} (\href{https://pwskills.com/learn/certificate/7cb6d99b-da82-45dd-9784-06513263a44c/}{PW Skills})}{Jan '24 -- Dec '24}
\end{jobshort}
\begin{jobshort}{\textbf{MERN Stack Development} (\href{https://mycourse.app/qWomCXFiY9wBahWJA}{Apna College})}{Dec '22 -- Oct '23}
\end{jobshort}


%----------------------------------------------------------------------------------------
%	Activities \& Achievements
%----------------------------------------------------------------------------------------


\section{Activities \& Achievements}
\begin{itemize}[leftmargin=1em, itemsep=4pt]

    \item \textbf{Code-A-Haunt Hackathon (Coding Blocks, LPU):} 
    Participated in a high-intensity coding and development sprint focused on rapid problem-solving and teamwork. Built an \textbf{AI Therapist} Application using Python, Django, and Google AI Studio, integrating the trained model into the backend through API-based communication.

    \item \textbf{Responsive CSS Challenge — 21 Days Bootcamp:} 
    Completed 21 mini-projects in 21 days, strengthening expertise in responsive design, media queries, accessibility, and SEO-friendly UI development. Created modern, scalable, and production-ready CSS layouts.

    \item \textbf{AlumniConnect Application (MERN, Socket.io, APIs):} 
    Developed during the Code Strome 36-Hour Hackathon organized by \textbf{Microsoft Learn Student Ambassadors}, where our team was awarded \textbf{Runner-Up}. Designed a real-time mentorship platform enabling students and alumni to connect through live chat, appointment scheduling, and role-based dashboards.

\end{itemize}

%----------------------------------------------------------------------------------------
%	EDUCATION
%----------------------------------------------------------------------------------------

\section{Education}
\begin{tabularx}{\linewidth}{@{} X r @{}}

    \textbf{Lovely Professional University} & Phagwara, Punjab \\
    Master of Computer Application (Hons. in AI/ML), in collaboration with \textbf{IBM}; CGPA: 8.0 & Aug '24 – Present \\[1.5pt]

    \textbf{Indira Gandhi National Open University} & Patna, Bihar \\
    Bachelor of Computer Application; Percentage: 62\% & Jul '19 – Dec '23 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Intermediate (PCM); Percentage: 70\% & Mar '17 – Mar '19 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Matriculation; Percentage: 75\% & Mar '16 – Feb '17 \\

\end{tabularx}

\end{document}

# %%
\documentclass[a4paper,11pt]{article}

%----------------------------------------------------------------------------------------
% PACKAGES
%----------------------------------------------------------------------------------------
\usepackage{url}
\usepackage{parskip}
\setlength{\parskip}{0pt}
\usepackage{color}
\usepackage{graphicx}
\usepackage[usenames,dvipsnames]{xcolor}
\usepackage[scale=0.95, top=1.25cm, bottom=1.25cm]{geometry}
\usepackage{fontspec} % Use fontspec to load system fonts
\setmainfont{EB Garamond} % Set the document font to Garamond
\usepackage{setspace} % Package for line spacing
\setstretch{1.05} % Increase line spacing by 10%
\usepackage{tabularx}
\usepackage{enumitem}
\newcolumntype{C}{>{\centering\arraybackslash}X}
\usepackage{supertabular}
\newlength{\fullcollw}
\setlength{\fullcollw}{0.47\textwidth}
\usepackage{titlesec}
\usepackage{multicol}
\usepackage{multirow}
\usepackage[style=authoryear,sorting=ynt, maxbibnames=2]{biblatex}
\usepackage[unicode, draft=false]{hyperref}
\definecolor{linkcolour}{rgb}{0,0.2,0.6}
\hypersetup{colorlinks,breaklinks,urlcolor=linkcolour,linkcolor=linkcolour}
\setlength\bibitemsep{1em}
\usepackage{fontawesome5}

%----------------------------------------------------------------------------------------
% CV LAYOUT
%----------------------------------------------------------------------------------------
\titleformat{\section}{\large\scshape\raggedright}{}{0em}{}[\titlerule]
\titlespacing{\section}{0pt}{3pt}{3pt}

\newenvironment{jobshort}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  }
  {
  }

\newenvironment{joblong}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  \begin{minipage}[t]{\linewidth}
  \begin{itemize}[nosep,after=\strut, leftmargin=1em, itemsep=0.5pt,label=\textbullet]
  }
  {
  \end{itemize}
  \end{minipage}
  }

%----------------------------------------------------------------------------------------
% BEGIN DOCUMENT
%----------------------------------------------------------------------------------------
\begin{document}

\pagestyle{empty}

%----------------------------------------------------------------------------------------
%	TITLE
%----------------------------------------------------------------------------------------

% \begin{tabularx}{\linewidth}{ @{}X X@{} }
% \huge{Your Name}\vspace{2pt} & \hfill \emoji{incoming-envelope} email@email.com \\
% \raisebox{-0.05\height}\faGithub\ username \ | \
% \raisebox{-0.00\height}\faLinkedin\ username \ | \ \raisebox{-0.05\height}\faGlobe \ mysite.com  & \hfill \emoji{calling} number
% \end{tabularx}

\begin{tabularx}{\linewidth}{@{} C @{}}
\Huge{Vicky Kumar} \\[7.5pt]
\href{https://github.com/pseudovicky}{\raisebox{-0.05\height}\faGithub\ pseudovicky} \ $|$ \ 
\href{https://linkedin.com/in/pseudovicky}{\raisebox{-0.05\height}\faLinkedin\ pseudovicky} \ $|$ \ 
\href{https://vickykumar.me}{\raisebox{-0.05\height}\faGlobe \ vickykumar.me} \ $|$ \ 
\href{mailto:sudovicky@gmail.com}{\raisebox{-0.05\height}\faEnvelope \ sudovicky@gmail.com} \ $|$ \ 
\href{tel:+917295818429}{\raisebox{-0.05\height}\faMobile \ +91 7295818429} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	SKILLS
%----------------------------------------------------------------------------------------
\section{Skills}
\begin{tabularx}{\linewidth}{@{}l X@{}}

Languages & \normalsize{Python, C/C++, Java, DSA, HTML, CSS, JavaScript, MySQL, ML, DL, NLP, Neural Networks, MLDLC } \\

Frameworks & \normalsize{React.js, Tailwind CSS, Bootstrap, Node.js, Express.js} \\

Libraries & \normalsize{NumPy, Pandas, Matplotlib, Seaborn, Scikit-learn, Folium, Keras, TensorFlow, NLTK, Plotly, OpenCV } \\

Tools / Platforms & \normalsize{MongoDB, MS SQL Server, IBM Cognos, IBM Cloud, Excel, Selenium, Canva, Figma, Power BI, Cisco Packet Tracer} \\

Soft Skills & \normalsize{Problem-Solving, Teamwork, Strategic Planning, Technical Writing, Information Synthesis, Attention to Detail} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	Project
%----------------------------------------------------------------------------------------

\section{Projects}
%	Project 1 
\begin{joblong}{\textbf{Old Car Price Prediction} — Python, Pandas, NumPy, Scikit-learn, AdaBoost, Web Scraping}{Aug '25}
\item Scraped real world car data from Quikr and Kaggle, performed cleaning, anomaly detection, and feature engineering using Adjusted R\textsuperscript{2}.
\item Built a Linear Regression model boosted with \textbf{AdaBoost}, improving accuracy and achieving an overall \textbf{R\textsuperscript{2} ≈ 0.92} with detailed error analysis. 
\end{joblong}

%	Project 2
\begin{joblong}{\textbf{Sorting Algorithm Visualizer} (\href{https://sort-visualiser-chi.vercel.app/}{Deployed on Vercel})}{May '25}
\item Built an interactive web tool to visualize major sorting algorithms in real time, enhancing understanding of time/space complexity.
\item Implemented nine algorithms with step-by-step animations and user controls for data size, randomness, and speed.
\item Designed a \textbf{Node.js + Express + Socket.IO} architecture for smooth execution streaming and a clean, responsive bar-graph UI.
\end{joblong}


\begin{joblong}{\textbf{Association Rule Mining for Retail Optimization} — Python, MLxtend, IBM Watson Studio, IBM Cloud}{Mar '25}
\item Built a market basket analysis system using \textbf{Apriori} and \textbf{FP-Growth} algorithms to find which products are frequently bought together.
\item Used \textbf{support, confidence, and lift} to create useful recommendations for product placement and combo offers in supermarkets.
\item Deployed the solution on \textbf{IBM Cloud} with Watson Studio for easy access and real-time insights to help improve sales decisions.
\end{joblong}


\begin{joblong}{\textbf{CheckInn} — MySQL, Node.js, Express, JavaScript, React \quad
\href{https://github.com/pseudovicky/CheckInn}{GitHub} \;|\;
\href{https://docs.google.com/document/d/13uZuB80_r-V9aIMEZW-nD5cQcaGiPV-5iy5fOFhbq6A/edit?usp=sharing}{Project Report}
}{Aug '24}
\item Built a full-stack hotel booking and management system using \textbf{MySQL}, Node.js, and JavaScript, designing optimized relational schemas, high-performance SQL queries, and secure booking workflows with responsive UI components.
\item Delivered dynamic stored procedures, triggers, and analytical SQL modules powering real-time operations and reporting.
\end{joblong}

\begin{joblong}{\textbf{Panic Buying Analysis During Early COVID-19} — Data Analysis, Google Mobility, Apple Mobility}{Aug '24}
\item Analyzed Google and Apple mobility datasets to track changes in essential shopping activity during the first COVID-19 wave and identify panic-buying behavior across regions.
\item Cleaned and visualized mobility trends to evaluate how lockdown announcements and movement restrictions influenced consumer stockpiling patterns.
\end{joblong}


%----------------------------------------------------------------------------------------
%	CERTIFICATIONS
%----------------------------------------------------------------------------------------

\section{Certificates}
\begin{jobshort}{\textbf{VLSI Design – MSME Professional Training} (\href{https://inleski.com/certificate.php?certificate=20250619IB7304617369}{INLESKI})}{Jun '25 -- Jul '25}
\end{jobshort}
\begin{jobshort}{\textbf{Responsive Web Design} (\href{https://www.freecodecamp.org/certification/fcc47b3390d-0c34-4d57-8948-2eac1209f8ea/responsive-web-design}{freeCodeCamp})}{Jul '25 -- Sep '25}
\end{jobshort}
\begin{jobshort}{\textbf{Machine Learning \& Data Visualization} (IBM)}{Oct '24 -- Jan '25}
\end{jobshort}
\begin{jobshort}{\textbf{Data Science Masters} (\href{https://pwskills.com/learn/certificate/7cb6d99b-da82-45dd-9784-06513263a44c/}{PW Skills})}{Jan '24 -- Dec '24}
\end{jobshort}
\begin{jobshort}{\textbf{MERN Stack Development} (\href{https://mycourse.app/qWomCXFiY9wBahWJA}{Apna College})}{Dec '22 -- Oct '23}
\end{jobshort}


%----------------------------------------------------------------------------------------
%	Activities \& Achievements
%----------------------------------------------------------------------------------------


\section{Activities \& Achievements}
\begin{itemize}[leftmargin=1em, itemsep=4pt]

    \item \textbf{Code-A-Haunt Hackathon (Coding Blocks, LPU):} 
    Participated in a high-intensity coding and development sprint focused on rapid problem-solving and teamwork. Built an \textbf{AI Therapist} Application using Python, Django, and Google AI Studio, integrating the trained model into the backend through API-based communication.

    \item \textbf{Responsive CSS Challenge — 21 Days Bootcamp:} 
    Completed 21 mini-projects in 21 days, strengthening expertise in responsive design, media queries, accessibility, and SEO-friendly UI development. Created modern, scalable, and production-ready CSS layouts.

    \item \textbf{AlumniConnect Application (MERN, Socket.io, APIs):} 
    Developed during the Code Strome 36-Hour Hackathon organized by \textbf{Microsoft Learn Student Ambassadors}, where our team was awarded \textbf{Runner-Up}. Designed a real-time mentorship platform enabling students and alumni to connect through live chat, appointment scheduling, and role-based dashboards.

\end{itemize}

%----------------------------------------------------------------------------------------
%	EDUCATION
%----------------------------------------------------------------------------------------

\section{Education}
\begin{tabularx}{\linewidth}{@{} X r @{}}

    \textbf{Lovely Professional University} & Phagwara, Punjab \\
    Master of Computer Application (Hons. in AI/ML), in collaboration with \textbf{IBM}; CGPA: 8.0 & Aug '24 – Present \\[1.5pt]

    \textbf{Indira Gandhi National Open University} & Patna, Bihar \\
    Bachelor of Computer Application; Percentage: 62\% & Jul '19 – Dec '23 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Intermediate (PCM); Percentage: 70\% & Mar '17 – Mar '19 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Matriculation; Percentage: 75\% & Mar '16 – Feb '17 \\

\end{tabularx}

\end{document}

# %%
\documentclass[a4paper,11pt]{article}

%----------------------------------------------------------------------------------------
% PACKAGES
%----------------------------------------------------------------------------------------
\usepackage{url}
\usepackage{parskip}
\setlength{\parskip}{0pt}
\usepackage{color}
\usepackage{graphicx}
\usepackage[usenames,dvipsnames]{xcolor}
\usepackage[scale=0.95, top=1.25cm, bottom=1.25cm]{geometry}
\usepackage{fontspec} % Use fontspec to load system fonts
\setmainfont{EB Garamond} % Set the document font to Garamond
\usepackage{setspace} % Package for line spacing
\setstretch{1.05} % Increase line spacing by 10%
\usepackage{tabularx}
\usepackage{enumitem}
\newcolumntype{C}{>{\centering\arraybackslash}X}
\usepackage{supertabular}
\newlength{\fullcollw}
\setlength{\fullcollw}{0.47\textwidth}
\usepackage{titlesec}
\usepackage{multicol}
\usepackage{multirow}
\usepackage[style=authoryear,sorting=ynt, maxbibnames=2]{biblatex}
\usepackage[unicode, draft=false]{hyperref}
\definecolor{linkcolour}{rgb}{0,0.2,0.6}
\hypersetup{colorlinks,breaklinks,urlcolor=linkcolour,linkcolor=linkcolour}
\setlength\bibitemsep{1em}
\usepackage{fontawesome5}

%----------------------------------------------------------------------------------------
% CV LAYOUT
%----------------------------------------------------------------------------------------
\titleformat{\section}{\large\scshape\raggedright}{}{0em}{}[\titlerule]
\titlespacing{\section}{0pt}{3pt}{3pt}

\newenvironment{jobshort}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  }
  {
  }

\newenvironment{joblong}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  \begin{minipage}[t]{\linewidth}
  \begin{itemize}[nosep,after=\strut, leftmargin=1em, itemsep=0.5pt,label=\textbullet]
  }
  {
  \end{itemize}
  \end{minipage}
  }

%----------------------------------------------------------------------------------------
% BEGIN DOCUMENT
%----------------------------------------------------------------------------------------
\begin{document}

\pagestyle{empty}

%----------------------------------------------------------------------------------------
%	TITLE
%----------------------------------------------------------------------------------------

% \begin{tabularx}{\linewidth}{ @{}X X@{} }
% \huge{Your Name}\vspace{2pt} & \hfill \emoji{incoming-envelope} email@email.com \\
% \raisebox{-0.05\height}\faGithub\ username \ | \
% \raisebox{-0.00\height}\faLinkedin\ username \ | \ \raisebox{-0.05\height}\faGlobe \ mysite.com  & \hfill \emoji{calling} number
% \end{tabularx}

\begin{tabularx}{\linewidth}{@{} C @{}}
\Huge{Vicky Kumar} \\[7.5pt]
\href{https://github.com/pseudovicky}{\raisebox{-0.05\height}\faGithub\ pseudovicky} \ $|$ \ 
\href{https://linkedin.com/in/pseudovicky}{\raisebox{-0.05\height}\faLinkedin\ pseudovicky} \ $|$ \ 
\href{https://vickykumar.me}{\raisebox{-0.05\height}\faGlobe \ vickykumar.me} \ $|$ \ 
\href{mailto:sudovicky@gmail.com}{\raisebox{-0.05\height}\faEnvelope \ sudovicky@gmail.com} \ $|$ \ 
\href{tel:+917295818429}{\raisebox{-0.05\height}\faMobile \ +91 7295818429} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	SKILLS
%----------------------------------------------------------------------------------------
\section{Skills}
\begin{tabularx}{\linewidth}{@{}l X@{}}

Languages & \normalsize{Python, C/C++, Java, DSA, HTML, CSS, JavaScript, MySQL, ML, DL, NLP, Neural Networks, MLDLC } \\

Frameworks & \normalsize{React.js, Tailwind CSS, Bootstrap, Node.js, Express.js} \\

Libraries & \normalsize{NumPy, Pandas, Matplotlib, Seaborn, Scikit-learn, Folium, Keras, TensorFlow, NLTK, Plotly, OpenCV } \\

Tools / Platforms & \normalsize{MongoDB, MS SQL Server, IBM Cognos, IBM Cloud, Excel, Selenium, Canva, Figma, Power BI, Cisco Packet Tracer} \\

Soft Skills & \normalsize{Problem-Solving, Teamwork, Strategic Planning, Technical Writing, Information Synthesis, Attention to Detail} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	Project
%----------------------------------------------------------------------------------------

\section{Projects}
%	Project 1 
\begin{joblong}{\textbf{Old Car Price Prediction} — Python, Pandas, NumPy, Scikit-learn, AdaBoost, Web Scraping}{Aug '25}
\item Scraped real world car data from Quikr and Kaggle, performed cleaning, anomaly detection, and feature engineering using Adjusted R\textsuperscript{2}.
\item Built a Linear Regression model boosted with \textbf{AdaBoost}, improving accuracy and achieving an overall \textbf{R\textsuperscript{2} ≈ 0.92} with detailed error analysis. 
\end{joblong}


\begin{joblong}{\textbf{Association Rule Mining for Retail Optimization} — Python, MLxtend, IBM Watson Studio, IBM Cloud}{Mar '25}
\item Built a market basket analysis system using \textbf{Apriori} and \textbf{FP-Growth} algorithms to find which products are frequently bought together.
\item Used \textbf{support, confidence, and lift} to create useful recommendations for product placement and combo offers in supermarkets.
\item Deployed the solution on \textbf{IBM Cloud} with Watson Studio for easy access and real-time insights to help improve sales decisions.
\end{joblong}


\begin{joblong}{\textbf{Panic Buying Analysis During Early COVID-19} — Data Analysis, Google Mobility, Apple Mobility}{Aug '24}
\item Analyzed Google and Apple mobility datasets to track changes in essential shopping activity during the first COVID-19 wave and identify panic-buying behavior across regions.
\item Cleaned and visualized mobility trends to evaluate how lockdown announcements and movement restrictions influenced consumer stockpiling patterns.
\end{joblong}


%----------------------------------------------------------------------------------------
%	CERTIFICATIONS
%----------------------------------------------------------------------------------------

\section{Certificates}
\begin{jobshort}{\textbf{VLSI Design – MSME Professional Training} (\href{https://inleski.com/certificate.php?certificate=20250619IB7304617369}{INLESKI})}{Jun '25 -- Jul '25}
\end{jobshort}
\begin{jobshort}{\textbf{Responsive Web Design} (\href{https://www.freecodecamp.org/certification/fcc47b3390d-0c34-4d57-8948-2eac1209f8ea/responsive-web-design}{freeCodeCamp})}{Jul '25 -- Sep '25}
\end{jobshort}
\begin{jobshort}{\textbf{Machine Learning \& Data Visualization} (IBM)}{Oct '24 -- Jan '25}
\end{jobshort}
\begin{jobshort}{\textbf{Data Science Masters} (\href{https://pwskills.com/learn/certificate/7cb6d99b-da82-45dd-9784-06513263a44c/}{PW Skills})}{Jan '24 -- Dec '24}
\end{jobshort}
\begin{jobshort}{\textbf{MERN Stack Development} (\href{https://mycourse.app/qWomCXFiY9wBahWJA}{Apna College})}{Dec '22 -- Oct '23}
\end{jobshort}


%----------------------------------------------------------------------------------------
%	Activities \& Achievements
%----------------------------------------------------------------------------------------


\section{Activities \& Achievements}
\begin{itemize}[leftmargin=1em, itemsep=4pt]

    \item \textbf{Code-A-Haunt Hackathon (Coding Blocks, LPU):} 
    Participated in a high-intensity coding and development sprint focused on rapid problem-solving and teamwork. Built an \textbf{AI Therapist} Application using Python, Django, and Google AI Studio, integrating the trained model into the backend through API-based communication.

    \item \textbf{Responsive CSS Challenge — 21 Days Bootcamp:} 
    Completed 21 mini-projects in 21 days, strengthening expertise in responsive design, media queries, accessibility, and SEO-friendly UI development. Created modern, scalable, and production-ready CSS layouts.

    \item \textbf{AlumniConnect Application (MERN, Socket.io, APIs):} 
    Developed during the Code Strome 36-Hour Hackathon organized by \textbf{Microsoft Learn Student Ambassadors}, where our team was awarded \textbf{Runner-Up}. Designed a real-time mentorship platform enabling students and alumni to connect through live chat, appointment scheduling, and role-based dashboards.

\end{itemize}

%----------------------------------------------------------------------------------------
%	EDUCATION
%----------------------------------------------------------------------------------------

\section{Education}
\begin{tabularx}{\linewidth}{@{} X r @{}}

    \textbf{Lovely Professional University} & Phagwara, Punjab \\
    Master of Computer Application (Hons. in AI/ML), in collaboration with \textbf{IBM}; CGPA: 8.0 & Aug '24 – Present \\[1.5pt]

    \textbf{Indira Gandhi National Open University} & Patna, Bihar \\
    Bachelor of Computer Application; Percentage: 62\% & Jul '19 – Dec '23 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Intermediate (PCM); Percentage: 70\% & Mar '17 – Mar '19 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Matriculation; Percentage: 75\% & Mar '16 – Feb '17 \\

\end{tabularx}

\end{document}
