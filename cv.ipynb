# %%
\documentclass[a4paper,11pt]{article}

%----------------------------------------------------------------------------------------
% PACKAGES
%----------------------------------------------------------------------------------------
\usepackage{url}
\usepackage{parskip}
\setlength{\parskip}{0pt}
\usepackage{color}
\usepackage{graphicx}
\usepackage[usenames,dvipsnames]{xcolor}
\usepackage[scale=0.95, top=1.25cm, bottom=1.25cm]{geometry}
\usepackage{fontspec} % Use fontspec to load system fonts
\setmainfont{EB Garamond} % Set the document font to Garamond
\usepackage{setspace} % Package for line spacing
\setstretch{1.05} % Increase line spacing by 10%
\usepackage{tabularx}
\usepackage{enumitem}
\newcolumntype{C}{>{\centering\arraybackslash}X}
\usepackage{supertabular}
\newlength{\fullcollw}
\setlength{\fullcollw}{0.47\textwidth}
\usepackage{titlesec}
\usepackage{multicol}
\usepackage{multirow}
\usepackage[style=authoryear,sorting=ynt, maxbibnames=2]{biblatex}
\usepackage[unicode, draft=false]{hyperref}
\definecolor{linkcolour}{rgb}{0,0.2,0.6}
\hypersetup{colorlinks,breaklinks,urlcolor=linkcolour,linkcolor=linkcolour}
\setlength\bibitemsep{1em}
\usepackage{fontawesome5}

%----------------------------------------------------------------------------------------
% CV LAYOUT
%----------------------------------------------------------------------------------------
\titleformat{\section}{\large\scshape\raggedright}{}{0em}{}[\titlerule]
\titlespacing{\section}{0pt}{3pt}{3pt}

\newenvironment{jobshort}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  }
  {
  }

\newenvironment{joblong}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  \begin{minipage}[t]{\linewidth}
  \begin{itemize}[nosep,after=\strut, leftmargin=1em, itemsep=0.5pt,label=\textbullet]
  }
  {
  \end{itemize}
  \end{minipage}
  }

%----------------------------------------------------------------------------------------
% BEGIN DOCUMENT
%----------------------------------------------------------------------------------------
\begin{document}

\pagestyle{empty}

%----------------------------------------------------------------------------------------
%	TITLE
%----------------------------------------------------------------------------------------

% \begin{tabularx}{\linewidth}{ @{}X X@{} }
% \huge{Your Name}\vspace{2pt} & \hfill \emoji{incoming-envelope} email@email.com \\
% \raisebox{-0.05\height}\faGithub\ username \ | \
% \raisebox{-0.00\height}\faLinkedin\ username \ | \ \raisebox{-0.05\height}\faGlobe \ mysite.com  & \hfill \emoji{calling} number
% \end{tabularx}

\begin{tabularx}{\linewidth}{@{} C @{}}
\Huge{Vicky Kumar} \\[7.5pt]
\href{https://github.com/pseudovicky}{\raisebox{-0.05\height}\faGithub\ pseudovicky} \ $|$ \ 
\href{https://linkedin.com/in/pseudovicky}{\raisebox{-0.05\height}\faLinkedin\ pseudovicky} \ $|$ \ 
\href{https://vickykumar.me}{\raisebox{-0.05\height}\faGlobe \ vickykumar.me} \ $|$ \ 
\href{mailto:sudovicky@gmail.com}{\raisebox{-0.05\height}\faEnvelope \ sudovicky@gmail.com} \ $|$ \ 
\href{tel:+917295818429}{\raisebox{-0.05\height}\faMobile \ +91 7295818429} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	SKILLS
%----------------------------------------------------------------------------------------
\section{Skills}
\begin{tabularx}{\linewidth}{@{}l X@{}}

Languages & \normalsize{Python, C/C++, Java, HTML, CSS, JavaScript, MySQL} \\

Frameworks & \normalsize{React.js, Tailwind CSS, Bootstrap, Node.js, Express.js} \\

Libraries & \normalsize{NumPy, Pandas, Matplotlib, Seaborn, Scikit-learn, Folium, Keras, TensorFlow } \\

Tools / Platforms & \normalsize{MongoDB, MS SQL Server, IBM Cognos, Excel, Selenium, Canva, Figma, Power BI, Cisco Packet Tracer} \\

Soft Skills & \normalsize{Problem-Solving, Teamwork \& Collaboration, Strategic Planning, Flexibility} \\
\end{tabularx}

%----------------------------------------------------------------------------------------
%	Experience
%----------------------------------------------------------------------------------------

\section{Experience}
\begin{joblong}{\textbf{Hariyalikart (Startup)} – Web Developer}{Jan 2024 – Jul 2024}
    \item Built and launched the company’s primary website \href{https://hariyalikart.com/}{hariyalikart.com}, supporting their mission of delivering smart-agriculture IoT and AI solutions to improve water usage and crop health.
    \item Developed full-stack features using the \textbf{MERN stack (MongoDB, Express.js, React.js, Node.js)}, integrating REST APIs and creating a fully responsive, mobile-first user experience.
    \item Collaborated with the tech team to implement feature enhancements, including real-time IoT sensor dashboards and dynamic content modules, improving farmer engagement and platform scalability.
    \item Optimized website performance—reducing load time, improving SEO, and enhancing mobile responsiveness—while ensuring maintainable code structure and effective version control practices.
\end{joblong}

%----------------------------------------------------------------------------------------
%	Internship
%----------------------------------------------------------------------------------------

\section{Internship \& Training}

\begin{joblong}{\textbf{VLSI Industrial Training \& Internship Program}}{Jun 2025 -- Jul 2025}
    \item Completed a comprehensive 7–8 week online industry-oriented training focused on digital logic design, CMOS fundamentals, Verilog/VHDL coding, RTL design, simulation, synthesis, and FPGA/ASIC workflows.
    \item Gained hands-on experience with real semiconductor design toolchains, worked on industry-aligned mini-projects, and achieved an \textbf{85\%} score, earning recognition as a top performer in the program.
\end{joblong}


%----------------------------------------------------------------------------------------
%	Project
%----------------------------------------------------------------------------------------


\section{Projects}

\begin{joblong}{\textbf{CloudDeck} — React, AWS S3, Tailwind CSS, Framer Motion}{Oct 2025}
\item Built \textbf{CloudDeck}, a serverless AWS S3 file management application to streamline internal cloud storage workflows.
\item Eliminated backend server costs by designing a fully client-side SPA that communicates directly with AWS S3 APIs.
\item Delivered a responsive and smooth UI using Tailwind CSS and Framer Motion, improving team efficiency in file management.
\end{joblong}


\begin{joblong}{\textbf{Old Car Price Prediction} — Python, Pandas, NumPy, Scikit-learn, AdaBoost, MERN Stack, Web Scraping, Vercel}{Aug 2025}

\item Scraped real-world used car data from Quikr.com and merged it with Kaggle datasets, followed by rigorous cleaning, anomaly detection, and preprocessing to create a high-quality training dataset.
\item Performed feature engineering and removed unnecessary or low-impact columns using \textbf{Adjusted R\textsuperscript{2}} to ensure only meaningful variables contributed to the model’s performance.
\item Built a baseline Linear Regression model, then boosted it with \textbf{AdaBoost}, improving prediction accuracy by nearly \textbf{20\%} and achieving an overall \textbf{R\textsuperscript{2} ≈ 0.92}.
\item Implemented the entire pipeline using Python, Pandas, NumPy, and scikit-learn, including dimensionality reduction, error analysis, and evaluation metrics such as R\textsuperscript{2}, MAE, and RMSE. Deployed the final system through a MERN-based web application hosted on \textbf{Vercel}, enabling users to interactively explore visual analytics (year, mileage, fuel type) and obtain accurate resale price predictions.
\end{joblong}


\begin{joblong}{\textbf{Sorting Algorithm Visualizer} (\href{https://sort-visualiser-chi.vercel.app/}{ Deployed on Vercel })}{May 2025}
\item Developed an interactive web application to visualize multiple sorting algorithms in real time, improving conceptual understanding of algorithmic behavior.
\item Implemented nine sorting algorithms—including Bubble Sort, Quick Sort, Merge Sort, Heap Sort, and Radix Sort—with step-by-step visualization of comparisons, swaps, and intermediate states.
\item Added customizable controls for array size, randomization, and sorting speed (Slow, Medium, Fast), enabling an adaptive and engaging learning experience.
\item Built a client–server architecture using \textbf{Node.js, Express.js, and Socket.IO} to stream algorithm execution steps and rendered progress through an intuitive bar-graph-based UI.
\end{joblong}





%----------------------------------------------------------------------------------------
%	CERTIFICATIONS
%----------------------------------------------------------------------------------------

\section{Certificates}
\begin{jobshort}{\textbf{VLSI Design – MSME Professional Training} (\href{https://inleski.com/certificate.php?certificate=20250619IB7304617369}{INLESKI})}{Jun 2025 -- Jul 2025}
\end{jobshort}
\begin{jobshort}{\textbf{Responsive Web Design} (\href{https://www.freecodecamp.org/certification/fcc47b3390d-0c34-4d57-8948-2eac1209f8ea/responsive-web-design}{freeCodeCamp})}{Jul 2025 -- Sep 2025}
\end{jobshort}
\begin{jobshort}{\textbf{Machine Learning \& Data Visualization} (IBM)}{Oct 2024 -- Jan 2025}
\end{jobshort}
\begin{jobshort}{\textbf{Data Science Masters} (\href{https://pwskills.com/learn/certificate/7cb6d99b-da82-45dd-9784-06513263a44c/}{PW Skills})}{Jan 2024 -- Dec 2024}
\end{jobshort}
\begin{jobshort}{\textbf{MERN Stack Development} (\href{https://mycourse.app/qWomCXFiY9wBahWJA}{Apna College})}{Dec 2022 -- Oct 2023}
\end{jobshort}


%----------------------------------------------------------------------------------------
%	Activities \& Achievements
%----------------------------------------------------------------------------------------


\section{Activities \& Achievements}
\begin{itemize}[leftmargin=1em, itemsep=4pt]

    \item \textbf{Code-A-Haunt Hackathon (Coding Blocks, LPU):} 
    Participated in a high-intensity coding and development sprint focused on rapid problem-solving and teamwork. Built an \textbf{AI Therapist} Application using Python, Django, and Google AI Studio, integrating the trained model into the backend through API-based communication.

    \item \textbf{Responsive CSS Challenge — 21 Days Bootcamp:} 
    Completed 21 mini-projects in 21 days, strengthening expertise in responsive design, media queries, accessibility, and SEO-friendly UI development. Created modern, scalable, and production-ready CSS layouts.

    \item \textbf{AlumniConnect Application (MERN, Socket.io, APIs):} 
    Developed during the Code Strome 36-Hour Hackathon organized by \textbf{Microsoft Learn Student Ambassadors}, where our team was awarded \textbf{Runner-Up}. Designed a real-time mentorship platform enabling students and alumni to connect through live chat, appointment scheduling, and role-based dashboards.

\end{itemize}


%----------------------------------------------------------------------------------------
%	EDUCATION
%----------------------------------------------------------------------------------------


\section{Education}
\begin{tabularx}{\linewidth}{@{} X r @{}}

    \textbf{Lovely Professional University} & Phagwara, Punjab \\
    Master of Computer Application (Hons. in AI/ML), in collaboration with \textbf{IBM}; CGPA: 8.0 & Aug 2024 – Present \\[1.5pt]

    \textbf{Indira Gandhi National Open University} & Patna, Bihar \\
    Bachelor of Computer Application; Percentage: 62\% & Jul 2019 – Dec 2023 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Intermediate (PCM); Percentage: 70\% & Mar 2017 – Mar 2019 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Matriculation; Percentage: 75\% & 2016 – 2017 \\

\end{tabularx}


\end{document}

# %%
\documentclass[a4paper,11pt]{article}

%----------------------------------------------------------------------------------------
% PACKAGES
%----------------------------------------------------------------------------------------
\usepackage{url}
\usepackage{parskip}
\setlength{\parskip}{0pt}
\usepackage{color}
\usepackage{graphicx}
\usepackage[usenames,dvipsnames]{xcolor}
\usepackage[scale=0.95, top=1.25cm, bottom=1.25cm]{geometry}
\usepackage{fontspec} % Use fontspec to load system fonts
\setmainfont{EB Garamond} % Set the document font to Garamond
\usepackage{setspace} % Package for line spacing
\setstretch{1.05} % Increase line spacing by 10%
\usepackage{tabularx}
\usepackage{enumitem}
\newcolumntype{C}{>{\centering\arraybackslash}X}
\usepackage{supertabular}
\newlength{\fullcollw}
\setlength{\fullcollw}{0.47\textwidth}
\usepackage{titlesec}
\usepackage{multicol}
\usepackage{multirow}
\usepackage[style=authoryear,sorting=ynt, maxbibnames=2]{biblatex}
\usepackage[unicode, draft=false]{hyperref}
\definecolor{linkcolour}{rgb}{0,0.2,0.6}
\hypersetup{colorlinks,breaklinks,urlcolor=linkcolour,linkcolor=linkcolour}
\setlength\bibitemsep{1em}
\usepackage{fontawesome5}

%----------------------------------------------------------------------------------------
% CV LAYOUT
%----------------------------------------------------------------------------------------
\titleformat{\section}{\large\scshape\raggedright}{}{0em}{}[\titlerule]
\titlespacing{\section}{0pt}{3pt}{3pt}

\newenvironment{jobshort}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  }
  {
  }

\newenvironment{joblong}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  \begin{minipage}[t]{\linewidth}
  \begin{itemize}[nosep,after=\strut, leftmargin=1em, itemsep=0.5pt,label=\textbullet]
  }
  {
  \end{itemize}
  \end{minipage}
  }

%----------------------------------------------------------------------------------------
% BEGIN DOCUMENT
%----------------------------------------------------------------------------------------
\begin{document}

\pagestyle{empty}

%----------------------------------------------------------------------------------------
%	TITLE
%----------------------------------------------------------------------------------------

% \begin{tabularx}{\linewidth}{ @{}X X@{} }
% \huge{Your Name}\vspace{2pt} & \hfill \emoji{incoming-envelope} email@email.com \\
% \raisebox{-0.05\height}\faGithub\ username \ | \
% \raisebox{-0.00\height}\faLinkedin\ username \ | \ \raisebox{-0.05\height}\faGlobe \ mysite.com  & \hfill \emoji{calling} number
% \end{tabularx}

\begin{tabularx}{\linewidth}{@{} C @{}}
\Huge{Vicky Kumar} \\[7.5pt]
\href{https://github.com/pseudovicky}{\raisebox{-0.05\height}\faGithub\ pseudovicky} \ $|$ \ 
\href{https://linkedin.com/in/pseudovicky}{\raisebox{-0.05\height}\faLinkedin\ pseudovicky} \ $|$ \ 
\href{https://vickykumar.me}{\raisebox{-0.05\height}\faGlobe \ vickykumar.me} \ $|$ \ 
\href{mailto:sudovicky@gmail.com}{\raisebox{-0.05\height}\faEnvelope \ sudovicky@gmail.com} \ $|$ \ 
\href{tel:+917295818429}{\raisebox{-0.05\height}\faMobile \ +91 7295818429} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	SKILLS
%----------------------------------------------------------------------------------------
\section{Skills}
\begin{tabularx}{\linewidth}{@{}l X@{}}

Languages & \normalsize{Python, C/C++, Java, DSA, HTML, CSS, JavaScript, MySQL} \\

Frameworks & \normalsize{React.js, Tailwind CSS, Bootstrap, Node.js, Express.js} \\

Libraries & \normalsize{NumPy, Pandas, Matplotlib, Seaborn, Scikit-learn, Folium, Keras, TensorFlow } \\

Tools / Platforms & \normalsize{MongoDB, MS SQL Server, IBM Cognos, Excel, Selenium, Canva, Figma, Power BI, Cisco Packet Tracer} \\

Soft Skills & \normalsize{Problem-Solving, Teamwork \& Collaboration, Strategic Planning, Flexibility} \\
\end{tabularx}

%----------------------------------------------------------------------------------------
%	Experience
%----------------------------------------------------------------------------------------

\section{Experience}
\begin{joblong}{\textbf{Hariyalikart (Startup)} – Web Developer}{Jan 2024 – Jul 2024}
    \item Built and launched the company’s primary website \href{https://hariyalikart.com/}{hariyalikart.com}, supporting their mission of delivering smart-agriculture IoT and AI solutions to improve water usage and crop health.
    \item Developed full-stack features using the \textbf{MERN stack (MongoDB, Express.js, React.js, Node.js)}, integrating REST APIs and creating a fully responsive, mobile-first user experience.
    \item Collaborated with the tech team to implement feature enhancements, including real-time IoT sensor dashboards and dynamic content modules, improving farmer engagement and platform scalability.
    \item Optimized website performance—reducing load time, improving SEO, and enhancing mobile responsiveness—while ensuring maintainable code structure and effective version control practices.
\end{joblong}

%----------------------------------------------------------------------------------------
%	Internship
%----------------------------------------------------------------------------------------

\section{Internship \& Training}

\begin{joblong}{\textbf{VLSI Industrial Training \& Internship Program}}{Jun 2025 -- Jul 2025}
    \item Completed a comprehensive 7–8 week online industry-oriented training focused on digital logic design, CMOS fundamentals, Verilog/VHDL coding, RTL design, simulation, synthesis, and FPGA/ASIC workflows.
    \item Gained hands-on experience with real semiconductor design toolchains, worked on industry-aligned mini-projects, and achieved an \textbf{85\%} score, earning recognition as a top performer in the program.
\end{joblong}

%----------------------------------------------------------------------------------------
%	Research and Publication
%----------------------------------------------------------------------------------------
\section*{Research \& Publications}
\begin{joblong}{\textbf{The Relationship Between Data and Information} — Correlation Analysis, Data Quality, Association Rule Mining}{ Nov 2025}
\item Conducting an IEEE-style research study examining the transformation of raw data into meaningful information through correlation analysis, data integrity evaluation, and statistical sensitivity methods.
\item Centered on \textbf{Association Rule Mining} (Apriori/FP-Growth) to uncover implicit relationships and reveal latent behavioral and operational insights within complex datasets.
\end{joblong}

\begin{joblong}{\textbf{Advanced Public Safety Surveillance System (APSSS)} — IoT, Computer Vision, AI}{2025}
\item Built a real-time public safety system capable of detecting suspicious objects, monitoring abnormal human activity, and identifying individuals through face recognition in public environments.
\item Implemented automated alerting with buzzer alarms and red-flag notifications for authorities when suspicious behavior or high-risk objects are detected.
\end{joblong}

%----------------------------------------------------------------------------------------
%	Project
%----------------------------------------------------------------------------------------


\section{Projects}

\begin{joblong}{\textbf{CloudDeck} — React, AWS S3, Tailwind CSS, Framer Motion}{Oct 2025}
\item Built \textbf{CloudDeck}, a serverless AWS S3 file management application to streamline internal cloud storage workflows.
\item Eliminated backend server costs by designing a fully client-side SPA that communicates directly with AWS S3 APIs.
\item Delivered a responsive and smooth UI using Tailwind CSS and Framer Motion, improving team efficiency in file management.
\end{joblong}


\begin{joblong}{\textbf{Old Car Price Prediction} — Python, Pandas, NumPy, Scikit-learn, AdaBoost, MERN Stack, Web Scraping, Vercel}{Aug 2025}

\item Scraped real-world used car data from Quikr.com and merged it with Kaggle datasets, followed by rigorous cleaning, anomaly detection, and preprocessing to create a high-quality training dataset.
\item Performed feature engineering and removed unnecessary or low-impact columns using \textbf{Adjusted R\textsuperscript{2}} to ensure only meaningful variables contributed to the model’s performance.
\item Built a baseline Linear Regression model, then boosted it with \textbf{AdaBoost}, improving prediction accuracy by nearly \textbf{20\%} and achieving an overall \textbf{R\textsuperscript{2} ≈ 0.92}.
\item Implemented the entire pipeline using Python, Pandas, NumPy, and scikit-learn, including dimensionality reduction, error analysis, and evaluation metrics such as R\textsuperscript{2}, MAE, and RMSE. Deployed the final system through a MERN-based web application hosted on \textbf{Vercel}, enabling users to interactively explore visual analytics (year, mileage, fuel type) and obtain accurate resale price predictions.
\end{joblong}


\begin{joblong}{\textbf{Sorting Algorithm Visualizer} (\href{https://sort-visualiser-chi.vercel.app/}{ Deployed on Vercel })}{May 2025}
\item Developed an interactive web application to visualize multiple sorting algorithms in real time, improving conceptual understanding of algorithmic behavior.
\item Implemented nine sorting algorithms—including Bubble Sort, Quick Sort, Merge Sort, Heap Sort, and Radix Sort—with step-by-step visualization of comparisons, swaps, and intermediate states.
\item Added customizable controls for array size, randomization, and sorting speed (Slow, Medium, Fast), enabling an adaptive and engaging learning experience.
\item Built a client–server architecture using \textbf{Node.js, Express.js, and Socket.IO} to stream algorithm execution steps and rendered progress through an intuitive bar-graph-based UI.
\end{joblong}

\begin{joblong}{\textbf{House Price Prediction} — Python, Pandas, Scikit-learn, Django, Kaggle, MongoDB}{Jan 2025}
\item Collected and integrated housing datasets from Kaggle and other external sources, creating a unified dataset followed by EDA, data cleaning, anomaly detection, duplicate removal, feature engineering, and dimensionality reduction to ensure model robustness.
\item Built and trained a Linear Regression model achieving an \textbf{R\textsuperscript{2} ≈ 0.89}, then improved accuracy using \textbf{AdaBoost}; evaluated performance using R\textsuperscript{2}, RMSE, and MAE for reliable predictions on unseen data.
\item Deployed the complete solution on a Django-based web platform with input forms for property details, integrated visual analytics (historical trends, yearly variations, profit margins), and conducted stochastic error analysis to generate actionable insights for stakeholders.
\end{joblong}

\begin{joblong}{\textbf{Excelify} — MERN Stack, RESTful API, JWT, Multer, SheetJS, Data Processing}{Dec 2024}
\item Developed a full-stack MERN application for automated Excel data processing, enabling secure uploads and efficient server-side handling of large and complex datasets.
\item Built a scalable RESTful API using Node.js and Express, implementing \textbf{JWT-based authentication}, \textbf{Multer} for file management, and \textbf{SheetJS} to parse and store structured Excel data in MongoDB.
\item Created a responsive, high-performance frontend with \textbf{React 19} and \textbf{Tailwind CSS}, featuring a drag-and-drop uploader and real-time data previews to enhance user experience and workflow efficiency.
\end{joblong}

\begin{joblong}{\textbf{Online Weather Application} — Java, AWT, Swing, MySQL (JDBC)}{Oct 2024}
\item Designed and developed an online weather application using Java, AWT, Swing, and MySQL (JDBC) to provide users with real-time weather updates and location-based forecasts.
\item Built an intuitive and responsive user interface using Java Swing, improving navigation, data visualization, and overall user experience.
\item Integrated a MySQL database for efficient storage and retrieval of weather records, ensuring data integrity and optimized query performance for faster response times.
\end{joblong}

\begin{joblong}{\textbf{CheckInn} — MySQL, Node.js, Express, JavaScript, React \quad
\href{https://github.com/pseudovicky/CheckInn}{GitHub} \;|\;
\href{https://docs.google.com/document/d/13uZuB80_r-V9aIMEZW-nD5cQcaGiPV-5iy5fOFhbq6A/edit?usp=sharing}{Project Report}
}{Aug 2024}
\item Built a full-stack hotel booking and management system using \textbf{MySQL}, Node.js, and JavaScript, designing optimized relational schemas, high-performance SQL queries, and secure booking workflows with responsive UI components.
\item Delivered dynamic stored procedures, triggers, and analytical SQL modules powering real-time operations and reporting.
\end{joblong}





%----------------------------------------------------------------------------------------
%	CERTIFICATIONS
%----------------------------------------------------------------------------------------

\section{Certificates}
\begin{jobshort}{\textbf{VLSI Design – MSME Professional Training} (\href{https://inleski.com/certificate.php?certificate=20250619IB7304617369}{INLESKI})}{Jun 2025 -- Jul 2025}
\end{jobshort}
\begin{jobshort}{\textbf{Responsive Web Design} (\href{https://www.freecodecamp.org/certification/fcc47b3390d-0c34-4d57-8948-2eac1209f8ea/responsive-web-design}{freeCodeCamp})}{Jul 2025 -- Sep 2025}
\end{jobshort}
\begin{jobshort}{\textbf{Machine Learning \& Data Visualization} (IBM)}{Oct 2024 -- Jan 2025}
\end{jobshort}
\begin{jobshort}{\textbf{Data Science Masters} (\href{https://pwskills.com/learn/certificate/7cb6d99b-da82-45dd-9784-06513263a44c/}{PW Skills})}{Jan 2024 -- Dec 2024}
\end{jobshort}
\begin{jobshort}{\textbf{MERN Stack Development} (\href{https://mycourse.app/qWomCXFiY9wBahWJA}{Apna College})}{Dec 2022 -- Oct 2023}
\end{jobshort}


%----------------------------------------------------------------------------------------
%	Activities \& Achievements
%----------------------------------------------------------------------------------------


\section{Activities \& Achievements}
\begin{itemize}[leftmargin=1em, itemsep=4pt]

    \item \textbf{Code-A-Haunt Hackathon (Coding Blocks, LPU):} 
    Participated in a high-intensity coding and development sprint focused on rapid problem-solving and teamwork. Built an \textbf{AI Therapist} Application using Python, Django, and Google AI Studio, integrating the trained model into the backend through API-based communication.

    \item \textbf{Responsive CSS Challenge — 21 Days Bootcamp:} 
    Completed 21 mini-projects in 21 days, strengthening expertise in responsive design, media queries, accessibility, and SEO-friendly UI development. Created modern, scalable, and production-ready CSS layouts.

    \item \textbf{AlumniConnect Application (MERN, Socket.io, APIs):} 
    Developed during the Code Strome 36-Hour Hackathon organized by \textbf{Microsoft Learn Student Ambassadors}, where our team was awarded \textbf{Runner-Up}. Designed a real-time mentorship platform enabling students and alumni to connect through live chat, appointment scheduling, and role-based dashboards.

\end{itemize}


%----------------------------------------------------------------------------------------
%	EDUCATION
%----------------------------------------------------------------------------------------


\section{Education}
\begin{tabularx}{\linewidth}{@{} X r @{}}

    \textbf{Lovely Professional University} & Phagwara, Punjab \\
    Master of Computer Application (Hons. in AI/ML), in collaboration with \textbf{IBM}; CGPA: 8.0 & Aug 2024 – Present \\[1.5pt]

    \textbf{Indira Gandhi National Open University} & Patna, Bihar \\
    Bachelor of Computer Application; Percentage: 62\% & Jul 2019 – Dec 2023 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Intermediate (PCM); Percentage: 70\% & Mar 2017 – Mar 2019 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Matriculation; Percentage: 75\% & 2016 – 2017 \\

\end{tabularx}


\end{document}

# %%
\documentclass[a4paper,11pt]{article}

%----------------------------------------------------------------------------------------
% PACKAGES
%----------------------------------------------------------------------------------------
\usepackage{url}
\usepackage{parskip}
\setlength{\parskip}{0pt}
\usepackage{color}
\usepackage{graphicx}
\usepackage[usenames,dvipsnames]{xcolor}
\usepackage[scale=0.95, top=1.25cm, bottom=1.25cm]{geometry}
\usepackage{fontspec} % Use fontspec to load system fonts
\setmainfont{EB Garamond} % Set the document font to Garamond
\usepackage{setspace} % Package for line spacing
\setstretch{1.05} % Increase line spacing by 10%
\usepackage{tabularx}
\usepackage{enumitem}
\newcolumntype{C}{>{\centering\arraybackslash}X}
\usepackage{supertabular}
\newlength{\fullcollw}
\setlength{\fullcollw}{0.47\textwidth}
\usepackage{titlesec}
\usepackage{multicol}
\usepackage{multirow}
\usepackage[style=authoryear,sorting=ynt, maxbibnames=2]{biblatex}
\usepackage[unicode, draft=false]{hyperref}
\definecolor{linkcolour}{rgb}{0,0.2,0.6}
\hypersetup{colorlinks,breaklinks,urlcolor=linkcolour,linkcolor=linkcolour}
\setlength\bibitemsep{1em}
\usepackage{fontawesome5}

%----------------------------------------------------------------------------------------
% CV LAYOUT
%----------------------------------------------------------------------------------------
\titleformat{\section}{\large\scshape\raggedright}{}{0em}{}[\titlerule]
\titlespacing{\section}{0pt}{3pt}{3pt}

\newenvironment{jobshort}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  }
  {
  }

\newenvironment{joblong}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  \begin{minipage}[t]{\linewidth}
  \begin{itemize}[nosep,after=\strut, leftmargin=1em, itemsep=0.5pt,label=\textbullet]
  }
  {
  \end{itemize}
  \end{minipage}
  }

%----------------------------------------------------------------------------------------
% BEGIN DOCUMENT
%----------------------------------------------------------------------------------------
\begin{document}

\pagestyle{empty}

%----------------------------------------------------------------------------------------
%	TITLE
%----------------------------------------------------------------------------------------

% \begin{tabularx}{\linewidth}{ @{}X X@{} }
% \huge{Your Name}\vspace{2pt} & \hfill \emoji{incoming-envelope} email@email.com \\
% \raisebox{-0.05\height}\faGithub\ username \ | \
% \raisebox{-0.00\height}\faLinkedin\ username \ | \ \raisebox{-0.05\height}\faGlobe \ mysite.com  & \hfill \emoji{calling} number
% \end{tabularx}

\begin{tabularx}{\linewidth}{@{} C @{}}
\Huge{Vicky Kumar} \\[7.5pt]
\href{https://github.com/pseudovicky}{\raisebox{-0.05\height}\faGithub\ pseudovicky} \ $|$ \ 
\href{https://linkedin.com/in/pseudovicky}{\raisebox{-0.05\height}\faLinkedin\ pseudovicky} \ $|$ \ 
\href{https://vickykumar.me}{\raisebox{-0.05\height}\faGlobe \ vickykumar.me} \ $|$ \ 
\href{mailto:sudovicky@gmail.com}{\raisebox{-0.05\height}\faEnvelope \ sudovicky@gmail.com} \ $|$ \ 
\href{tel:+917295818429}{\raisebox{-0.05\height}\faMobile \ +91 7295818429} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	SKILLS
%----------------------------------------------------------------------------------------
\section{Skills}
\begin{tabularx}{\linewidth}{@{}l X@{}}

Languages & \normalsize{Python, C/C++, Java, DSA, HTML, CSS, JavaScript, MySQL} \\

Frameworks & \normalsize{React.js, Tailwind CSS, Bootstrap, Node.js, Express.js} \\

Libraries & \normalsize{NumPy, Pandas, Matplotlib, Seaborn, Scikit-learn, Folium, Keras, TensorFlow } \\

Tools / Platforms & \normalsize{MongoDB, MS SQL Server, IBM Cognos, Excel, Selenium, Canva, Figma, Power BI, Cisco Packet Tracer} \\

Soft Skills & \normalsize{Problem-Solving, Teamwork \& Collaboration, Strategic Planning, Flexibility} \\
\end{tabularx}

%----------------------------------------------------------------------------------------
%	Experience
%----------------------------------------------------------------------------------------

\section{Experience}
\begin{joblong}{\textbf{Hariyalikart (Startup)} – Web Developer}{Jan 2024 – Jul 2024}
    \item Built and launched the company’s primary website \href{https://hariyalikart.com/}{hariyalikart.com}, supporting their mission of delivering smart-agriculture IoT and AI solutions to improve water usage and crop health.
    \item Developed full-stack features using the \textbf{MERN stack (MongoDB, Express.js, React.js, Node.js)}, integrating REST APIs and creating a fully responsive, mobile-first user experience.
    \item Collaborated with the tech team to implement feature enhancements, including real-time IoT sensor dashboards and dynamic content modules, improving farmer engagement and platform scalability.
    \item Optimized website performance—reducing load time, improving SEO, and enhancing mobile responsiveness—while ensuring maintainable code structure and effective version control practices.
\end{joblong}

%----------------------------------------------------------------------------------------
%	Internship
%----------------------------------------------------------------------------------------

\section{Internship \& Training}

\begin{joblong}{\textbf{VLSI Industrial Training \& Internship Program}}{Jun 2025 -- Jul 2025}
    \item Completed a comprehensive 7–8 week online industry-oriented training focused on digital logic design, CMOS fundamentals, Verilog/VHDL coding, RTL design, simulation, synthesis, and FPGA/ASIC workflows.
    \item Gained hands-on experience with real semiconductor design toolchains, worked on industry-aligned mini-projects, and achieved an \textbf{85\%} score, earning recognition as a top performer in the program.
\end{joblong}

%----------------------------------------------------------------------------------------
%	Research and Publication
%----------------------------------------------------------------------------------------
\section*{Research \& Publications}
\begin{joblong}{\textbf{The Relationship Between Data and Information} — Correlation Analysis, Data Quality, Association Rule Mining}{ Nov 2025}
\item Conducting an IEEE-style research study examining the transformation of raw data into meaningful information through correlation analysis, data integrity evaluation, and statistical sensitivity methods.
\item Centered on \textbf{Association Rule Mining} (Apriori/FP-Growth) to uncover implicit relationships and reveal latent behavioral and operational insights within complex datasets.
\end{joblong}

%----------------------------------------------------------------------------------------
%	Project
%----------------------------------------------------------------------------------------


\section{Projects}

\begin{joblong}{\textbf{Old Car Price Prediction} — Python, Pandas, NumPy, Scikit-learn, AdaBoost, MERN Stack, Web Scraping, Vercel}{Aug 2025}

\item Scraped real-world used car data from Quikr.com and merged it with Kaggle datasets, followed by rigorous cleaning, anomaly detection, and preprocessing to create a high-quality training dataset.
\item Performed feature engineering and removed unnecessary or low-impact columns using \textbf{Adjusted R\textsuperscript{2}} to ensure only meaningful variables contributed to the model’s performance.
\item Built a baseline Linear Regression model, then boosted it with \textbf{AdaBoost}, improving prediction accuracy by nearly \textbf{20\%} and achieving an overall \textbf{R\textsuperscript{2} ≈ 0.92}.
\item Implemented the entire pipeline using Python, Pandas, NumPy, and scikit-learn, including dimensionality reduction, error analysis, and evaluation metrics such as R\textsuperscript{2}, MAE, and RMSE. Deployed the final system through a MERN-based web application hosted on \textbf{Vercel}, enabling users to interactively explore visual analytics (year, mileage, fuel type) and obtain accurate resale price predictions.
\end{joblong}

\begin{joblong}{\textbf{CheckInn} — MySQL, Node.js, Express, JavaScript, React \quad
\href{https://github.com/pseudovicky/CheckInn}{GitHub} \;|\;
\href{https://docs.google.com/document/d/13uZuB80_r-V9aIMEZW-nD5cQcaGiPV-5iy5fOFhbq6A/edit?usp=sharing}{Project Report}
}{Aug 2024}
\item Built a full-stack hotel booking and management system using \textbf{MySQL}, Node.js, and JavaScript, designing optimized relational schemas, high-performance SQL queries, and secure booking workflows with responsive UI components.
\item Delivered dynamic stored procedures, triggers, and analytical SQL modules powering real-time operations and reporting.
\end{joblong}

\begin{joblong}{\textbf{Sorting Algorithm Visualizer} (\href{https://sort-visualiser-chi.vercel.app/}{ Deployed on Vercel })}{May 2025}
\item Developed an interactive web application to visualize multiple sorting algorithms in real time, improving conceptual understanding of algorithmic behavior.
\item Implemented nine sorting algorithms—including Bubble Sort, Quick Sort, Merge Sort, Heap Sort, and Radix Sort—with step-by-step visualization of comparisons, swaps, and intermediate states.
\item Added customizable controls for array size, randomization, and sorting speed (Slow, Medium, Fast), enabling an adaptive and engaging learning experience.
\item Built a client–server architecture using \textbf{Node.js, Express.js, and Socket.IO} to stream algorithm execution steps and rendered progress through an intuitive bar-graph-based UI.
\end{joblong}

\begin{joblong}{\textbf{House Price Prediction} — Python, Pandas, Scikit-learn, Django, Kaggle, MongoDB}{Jan 2025}
\item Collected and integrated housing datasets from Kaggle and other external sources, creating a unified dataset followed by EDA, data cleaning, anomaly detection, duplicate removal, feature engineering, and dimensionality reduction to ensure model robustness.
\item Built and trained a Linear Regression model achieving an \textbf{R\textsuperscript{2} ≈ 0.89}, then improved accuracy using \textbf{AdaBoost}; evaluated performance using R\textsuperscript{2}, RMSE, and MAE for reliable predictions on unseen data.
\item Deployed the complete solution on a Django-based web platform with input forms for property details, integrated visual analytics (historical trends, yearly variations, profit margins), and conducted stochastic error analysis to generate actionable insights for stakeholders.
\end{joblong}

\begin{joblong}{\textbf{Excelify} — MERN Stack, RESTful API, JWT, Multer, SheetJS, Data Processing}{Dec 2024}
\item Developed a full-stack MERN application for automated Excel data processing, enabling secure uploads and efficient server-side handling of large and complex datasets.
\item Built a scalable RESTful API using Node.js and Express, implementing \textbf{JWT-based authentication}, \textbf{Multer} for file management, and \textbf{SheetJS} to parse and store structured Excel data in MongoDB.
\item Created a responsive, high-performance frontend with \textbf{React 19} and \textbf{Tailwind CSS}, featuring a drag-and-drop uploader and real-time data previews to enhance user experience and workflow efficiency.
\end{joblong}

\begin{joblong}{\textbf{Online Weather Application} — Java, AWT, Swing, MySQL (JDBC)}{Oct 2024}
\item Designed and developed an online weather application using Java, AWT, Swing, and MySQL (JDBC) to provide users with real-time weather updates and location-based forecasts.
\item Built an intuitive and responsive user interface using Java Swing, improving navigation, data visualization, and overall user experience.
\item Integrated a MySQL database for efficient storage and retrieval of weather records, ensuring data integrity and optimized query performance for faster response times.
\end{joblong}







%----------------------------------------------------------------------------------------
%	CERTIFICATIONS
%----------------------------------------------------------------------------------------

\section{Certificates}
\begin{jobshort}{\textbf{VLSI Design – MSME Professional Training} (\href{https://inleski.com/certificate.php?certificate=20250619IB7304617369}{INLESKI})}{Jun 2025 -- Jul 2025}
\end{jobshort}
\begin{jobshort}{\textbf{Responsive Web Design} (\href{https://www.freecodecamp.org/certification/fcc47b3390d-0c34-4d57-8948-2eac1209f8ea/responsive-web-design}{freeCodeCamp})}{Jul 2025 -- Sep 2025}
\end{jobshort}
\begin{jobshort}{\textbf{Machine Learning \& Data Visualization} (IBM)}{Oct 2024 -- Jan 2025}
\end{jobshort}
\begin{jobshort}{\textbf{Data Science Masters} (\href{https://pwskills.com/learn/certificate/7cb6d99b-da82-45dd-9784-06513263a44c/}{PW Skills})}{Jan 2024 -- Dec 2024}
\end{jobshort}
\begin{jobshort}{\textbf{MERN Stack Development} (\href{https://mycourse.app/qWomCXFiY9wBahWJA}{Apna College})}{Dec 2022 -- Oct 2023}
\end{jobshort}


%----------------------------------------------------------------------------------------
%	Activities \& Achievements
%----------------------------------------------------------------------------------------


\section{Activities \& Achievements}
\begin{itemize}[leftmargin=1em, itemsep=4pt]

    \item \textbf{Code-A-Haunt Hackathon (Coding Blocks, LPU):} 
    Participated in a high-intensity coding and development sprint focused on rapid problem-solving and teamwork. Built an \textbf{AI Therapist} Application using Python, Django, and Google AI Studio, integrating the trained model into the backend through API-based communication.

    \item \textbf{Responsive CSS Challenge — 21 Days Bootcamp:} 
    Completed 21 mini-projects in 21 days, strengthening expertise in responsive design, media queries, accessibility, and SEO-friendly UI development. Created modern, scalable, and production-ready CSS layouts.

    \item \textbf{AlumniConnect Application (MERN, Socket.io, APIs):} 
    Developed during the Code Strome 36-Hour Hackathon organized by \textbf{Microsoft Learn Student Ambassadors}, where our team was awarded \textbf{Runner-Up}. Designed a real-time mentorship platform enabling students and alumni to connect through live chat, appointment scheduling, and role-based dashboards.

\end{itemize}


%----------------------------------------------------------------------------------------
%	EDUCATION
%----------------------------------------------------------------------------------------


\section{Education}
\begin{tabularx}{\linewidth}{@{} X r @{}}

    \textbf{Lovely Professional University} & Phagwara, Punjab \\
    Master of Computer Application (Hons. in AI/ML), in collaboration with \textbf{IBM}; CGPA: 8.0 & Aug 2024 – Present \\[1.5pt]

    \textbf{Indira Gandhi National Open University} & Patna, Bihar \\
    Bachelor of Computer Application; Percentage: 62\% & Jul 2019 – Dec 2023 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Intermediate (PCM); Percentage: 70\% & Mar 2017 – Mar 2019 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Matriculation; Percentage: 75\% & 2016 – 2017 \\

\end{tabularx}


\end{document}

# %%
# General Resume

# %%
\documentclass[a4paper,11pt]{article}

%----------------------------------------------------------------------------------------
% PACKAGES
%----------------------------------------------------------------------------------------
\usepackage{url}
\usepackage{parskip}
\setlength{\parskip}{0pt}
\usepackage{color}
\usepackage{graphicx}
\usepackage[usenames,dvipsnames]{xcolor}
\usepackage[scale=0.95, top=1.25cm, bottom=1.25cm]{geometry}
\usepackage{fontspec} % Use fontspec to load system fonts
\setmainfont{EB Garamond} % Set the document font to Garamond
\usepackage{setspace} % Package for line spacing
\setstretch{1.05} % Increase line spacing by 10%
\usepackage{tabularx}
\usepackage{enumitem}
\newcolumntype{C}{>{\centering\arraybackslash}X}
\usepackage{supertabular}
\newlength{\fullcollw}
\setlength{\fullcollw}{0.47\textwidth}
\usepackage{titlesec}
\usepackage{multicol}
\usepackage{multirow}
\usepackage[style=authoryear,sorting=ynt, maxbibnames=2]{biblatex}
\usepackage[unicode, draft=false]{hyperref}
\definecolor{linkcolour}{rgb}{0,0.2,0.6}
\hypersetup{colorlinks,breaklinks,urlcolor=linkcolour,linkcolor=linkcolour}
\setlength\bibitemsep{1em}
\usepackage{fontawesome5}

%----------------------------------------------------------------------------------------
% CV LAYOUT
%----------------------------------------------------------------------------------------
\titleformat{\section}{\large\scshape\raggedright}{}{0em}{}[\titlerule]
\titlespacing{\section}{0pt}{3pt}{3pt}

\newenvironment{jobshort}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  }
  {
  }

\newenvironment{joblong}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  \begin{minipage}[t]{\linewidth}
  \begin{itemize}[nosep,after=\strut, leftmargin=1em, itemsep=0.5pt,label=\textbullet]
  }
  {
  \end{itemize}
  \end{minipage}
  }

%----------------------------------------------------------------------------------------
% BEGIN DOCUMENT
%----------------------------------------------------------------------------------------
\begin{document}

\pagestyle{empty}

%----------------------------------------------------------------------------------------
%	TITLE
%----------------------------------------------------------------------------------------

% \begin{tabularx}{\linewidth}{ @{}X X@{} }
% \huge{Your Name}\vspace{2pt} & \hfill \emoji{incoming-envelope} email@email.com \\
% \raisebox{-0.05\height}\faGithub\ username \ | \
% \raisebox{-0.00\height}\faLinkedin\ username \ | \ \raisebox{-0.05\height}\faGlobe \ mysite.com  & \hfill \emoji{calling} number
% \end{tabularx}

\begin{tabularx}{\linewidth}{@{} C @{}}
\Huge{Vicky Kumar} \\[7.5pt]
\href{https://github.com/pseudovicky}{\raisebox{-0.05\height}\faGithub\ pseudovicky} \ $|$ \ 
\href{https://linkedin.com/in/pseudovicky}{\raisebox{-0.05\height}\faLinkedin\ pseudovicky} \ $|$ \ 
\href{https://vickykumar.me}{\raisebox{-0.05\height}\faGlobe \ vickykumar.me} \ $|$ \ 
\href{mailto:sudovicky@gmail.com}{\raisebox{-0.05\height}\faEnvelope \ sudovicky@gmail.com} \ $|$ \ 
\href{tel:+917295818429}{\raisebox{-0.05\height}\faMobile \ +91 7295818429} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	SKILLS
%----------------------------------------------------------------------------------------
\section{Skills}
\begin{tabularx}{\linewidth}{@{}l X@{}}

Languages & \normalsize{Python, C/C++, Java, DSA, HTML, CSS, JavaScript, MySQL} \\

Frameworks & \normalsize{React.js, Tailwind CSS, Bootstrap, Node.js, Express.js} \\

Libraries & \normalsize{NumPy, Pandas, Matplotlib, Seaborn, Scikit-learn, Folium, Keras, TensorFlow } \\

Tools / Platforms & \normalsize{MongoDB, MS SQL Server, IBM Cognos, Excel, Selenium, Canva, Figma, Power BI, Cisco Packet Tracer} \\

Soft Skills & \normalsize{Problem-Solving, Teamwork \& Collaboration, Strategic Planning, Flexibility} \\
\end{tabularx}

%----------------------------------------------------------------------------------------
%	Experience
%----------------------------------------------------------------------------------------

\section{Experience}
\begin{joblong}{\textbf{Hariyalikart (Startup)} – Web Developer}{Jan 2024 – Jul 2024}
    \item Built and launched the company’s primary website \href{https://hariyalikart.com/}{hariyalikart.com}, supporting their mission of delivering smart-agriculture IoT and AI solutions to improve water usage and crop health.
    \item Developed full-stack features using the \textbf{MERN stack (MongoDB, Express.js, React.js, Node.js)}, integrating REST APIs and creating a fully responsive, mobile-first user experience.
    \item Collaborated with the tech team to implement feature enhancements, including real-time IoT sensor dashboards and dynamic content modules, improving farmer engagement and platform scalability.
    \item Optimized website performance—reducing load time, improving SEO, and enhancing mobile responsiveness—while ensuring maintainable code structure and effective version control practices.
\end{joblong}


%----------------------------------------------------------------------------------------
%	Research and Publication
%----------------------------------------------------------------------------------------
\section*{Research \& Publications}
\begin{joblong}{\textbf{The Relationship Between Data and Information} — Correlation Analysis, Data Quality, Association Rule Mining}{ Nov 2025}
\item Conducting an IEEE-style research study examining the transformation of raw data into meaningful information through correlation analysis, data integrity evaluation, and statistical sensitivity methods.
\item Centered on \textbf{Association Rule Mining} (Apriori/FP-Growth) to uncover implicit relationships and reveal latent behavioral and operational insights within complex datasets.
\end{joblong}

%----------------------------------------------------------------------------------------
%	Project
%----------------------------------------------------------------------------------------


\section{Projects}

\begin{joblong}{\textbf{Old Car Price Prediction} — Python, Pandas, NumPy, Scikit-learn, AdaBoost, MERN Stack, Web Scraping, Vercel}{Aug 2025}

\item Scraped real-world used car data from Quikr.com and merged it with Kaggle datasets, followed by rigorous cleaning, anomaly detection, and preprocessing to create a high-quality training dataset.
\item Performed feature engineering and removed unnecessary or low-impact columns using \textbf{Adjusted R\textsuperscript{2}} to ensure only meaningful variables contributed to the model’s performance.
\item Built a baseline Linear Regression model, then boosted it with \textbf{AdaBoost}, improving prediction accuracy by nearly \textbf{20\%} and achieving an overall \textbf{R\textsuperscript{2} ≈ 0.92}.
\item Implemented the entire pipeline using Python, Pandas, NumPy, and scikit-learn, including dimensionality reduction, error analysis, and evaluation metrics such as R\textsuperscript{2}, MAE, and RMSE. Deployed the final system through a MERN-based web application hosted on \textbf{Vercel}, enabling users to interactively explore visual analytics (year, mileage, fuel type) and obtain accurate resale price predictions.
\end{joblong}


\begin{joblong}{\textbf{Sorting Algorithm Visualizer} (\href{https://sort-visualiser-chi.vercel.app/}{ Deployed on Vercel })}{May 2025}
\item Developed an interactive web application to visualize multiple sorting algorithms in real time, improving conceptual understanding of algorithmic behavior.
\item Implemented nine sorting algorithms—including Bubble Sort, Quick Sort, Merge Sort, Heap Sort, and Radix Sort—with step-by-step visualization of comparisons, swaps, and intermediate states.
\item Added customizable controls for array size, randomization, and sorting speed (Slow, Medium, Fast), enabling an adaptive and engaging learning experience.
\item Built a client–server architecture using \textbf{Node.js, Express.js, and Socket.IO} to stream algorithm execution steps and rendered progress through an intuitive bar-graph-based UI.
\end{joblong}

\begin{joblong}{\textbf{House Price Prediction} — Python, Pandas, Scikit-learn, Django, Kaggle, MongoDB}{Jan 2025}
\item Collected and integrated housing datasets from Kaggle and other external sources, creating a unified dataset followed by EDA, data cleaning, anomaly detection, duplicate removal, feature engineering, and dimensionality reduction to ensure model robustness.
\item Built and trained a Linear Regression model achieving an \textbf{R\textsuperscript{2} ≈ 0.89}, then improved accuracy using \textbf{AdaBoost}; evaluated performance using R\textsuperscript{2}, RMSE, and MAE for reliable predictions on unseen data.
\item Deployed the complete solution on a Django-based web platform with input forms for property details, integrated visual analytics (historical trends, yearly variations, profit margins), and conducted stochastic error analysis to generate actionable insights for stakeholders.
\end{joblong}

\begin{joblong}{\textbf{Excelify} — MERN Stack, RESTful API, JWT, Multer, SheetJS, Data Processing}{Dec 2024}
\item Developed a full-stack MERN application for automated Excel data processing, enabling secure uploads and efficient server-side handling of large and complex datasets.
\item Built a scalable RESTful API using Node.js and Express, implementing \textbf{JWT-based authentication}, \textbf{Multer} for file management, and \textbf{SheetJS} to parse and store structured Excel data in MongoDB.
\item Created a responsive, high-performance frontend with \textbf{React 19} and \textbf{Tailwind CSS}, featuring a drag-and-drop uploader and real-time data previews to enhance user experience and workflow efficiency.
\end{joblong}

\begin{joblong}{\textbf{CheckInn} — MySQL, Node.js, Express, JavaScript, React \quad
\href{https://github.com/pseudovicky/CheckInn}{GitHub} \;|\;
\href{https://docs.google.com/document/d/13uZuB80_r-V9aIMEZW-nD5cQcaGiPV-5iy5fOFhbq6A/edit?usp=sharing}{Project Report}
}{Aug 2024}
\item Built a full-stack hotel booking and management system using \textbf{MySQL}, Node.js, and JavaScript, designing optimized relational schemas, high-performance SQL queries, and secure booking workflows with responsive UI components.
\item Delivered dynamic stored procedures, triggers, and analytical SQL modules powering real-time operations and reporting.
\end{joblong}

\begin{joblong}{\textbf{Online Weather Application} — Java, AWT, Swing, MySQL (JDBC)}{Oct 2024}
\item Designed and developed an online weather application using Java, AWT, Swing, and MySQL (JDBC) to provide users with real-time weather updates and location-based forecasts.
\item Built an intuitive and responsive user interface using Java Swing, improving navigation, data visualization, and overall user experience.
\item Integrated a MySQL database for efficient storage and retrieval of weather records, ensuring data integrity and optimized query performance for faster response times.
\end{joblong}







%----------------------------------------------------------------------------------------
%	CERTIFICATIONS
%----------------------------------------------------------------------------------------

\section{Certificates}
\begin{jobshort}{\textbf{VLSI Design – MSME Professional Training} (\href{https://inleski.com/certificate.php?certificate=20250619IB7304617369}{INLESKI})}{Jun 2025 -- Jul 2025}
\end{jobshort}
\begin{jobshort}{\textbf{Responsive Web Design} (\href{https://www.freecodecamp.org/certification/fcc47b3390d-0c34-4d57-8948-2eac1209f8ea/responsive-web-design}{freeCodeCamp})}{Jul 2025 -- Sep 2025}
\end{jobshort}
\begin{jobshort}{\textbf{Machine Learning \& Data Visualization} (IBM)}{Oct 2024 -- Jan 2025}
\end{jobshort}
\begin{jobshort}{\textbf{Data Science Masters} (\href{https://pwskills.com/learn/certificate/7cb6d99b-da82-45dd-9784-06513263a44c/}{PW Skills})}{Jan 2024 -- Dec 2024}
\end{jobshort}
\begin{jobshort}{\textbf{MERN Stack Development} (\href{https://mycourse.app/qWomCXFiY9wBahWJA}{Apna College})}{Dec 2022 -- Oct 2023}
\end{jobshort}


%----------------------------------------------------------------------------------------
%	Activities \& Achievements
%----------------------------------------------------------------------------------------


\section{Activities \& Achievements}
\begin{itemize}[leftmargin=1em, itemsep=4pt]

    \item \textbf{Code-A-Haunt Hackathon (Coding Blocks, LPU):} 
    Participated in a high-intensity coding and development sprint focused on rapid problem-solving and teamwork. Built an \textbf{AI Therapist} Application using Python, Django, and Google AI Studio, integrating the trained model into the backend through API-based communication.

    \item \textbf{Responsive CSS Challenge — 21 Days Bootcamp:} 
    Completed 21 mini-projects in 21 days, strengthening expertise in responsive design, media queries, accessibility, and SEO-friendly UI development. Created modern, scalable, and production-ready CSS layouts.

    \item \textbf{AlumniConnect Application (MERN, Socket.io, APIs):} 
    Developed during the Code Strome 36-Hour Hackathon organized by \textbf{Microsoft Learn Student Ambassadors}, where our team was awarded \textbf{Runner-Up}. Designed a real-time mentorship platform enabling students and alumni to connect through live chat, appointment scheduling, and role-based dashboards.

\end{itemize}


%----------------------------------------------------------------------------------------
%	EDUCATION
%----------------------------------------------------------------------------------------


\section{Education}
\begin{tabularx}{\linewidth}{@{} X r @{}}

    \textbf{Lovely Professional University} & Phagwara, Punjab \\
    Master of Computer Application (Hons. in AI/ML), in collaboration with \textbf{IBM}; CGPA: 8.0 & Aug 2024 – Present \\[1.5pt]

    \textbf{Indira Gandhi National Open University} & Patna, Bihar \\
    Bachelor of Computer Application; Percentage: 62\% & Jul 2019 – Dec 2023 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Intermediate (PCM); Percentage: 70\% & Mar 2017 – Mar 2019 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Matriculation; Percentage: 75\% & 2016 – 2017 \\

\end{tabularx}


\end{document}

# %%
\documentclass[a4paper,11pt]{article}

%----------------------------------------------------------------------------------------
% PACKAGES
%----------------------------------------------------------------------------------------
\usepackage{url}
\usepackage{parskip}
\setlength{\parskip}{0pt}
\usepackage{color}
\usepackage{graphicx}
\usepackage[usenames,dvipsnames]{xcolor}
\usepackage[scale=0.95, top=1.25cm, bottom=1.25cm]{geometry}
\usepackage{fontspec} % Use fontspec to load system fonts
\setmainfont{EB Garamond} % Set the document font to Garamond
\usepackage{setspace} % Package for line spacing
\setstretch{1.05} % Increase line spacing by 10%
\usepackage{tabularx}
\usepackage{enumitem}
\newcolumntype{C}{>{\centering\arraybackslash}X}
\usepackage{supertabular}
\newlength{\fullcollw}
\setlength{\fullcollw}{0.47\textwidth}
\usepackage{titlesec}
\usepackage{multicol}
\usepackage{multirow}
\usepackage[style=authoryear,sorting=ynt, maxbibnames=2]{biblatex}
\usepackage[unicode, draft=false]{hyperref}
\definecolor{linkcolour}{rgb}{0,0.2,0.6}
\hypersetup{colorlinks,breaklinks,urlcolor=linkcolour,linkcolor=linkcolour}
\setlength\bibitemsep{1em}
\usepackage{fontawesome5}

%----------------------------------------------------------------------------------------
% CV LAYOUT
%----------------------------------------------------------------------------------------
\titleformat{\section}{\large\scshape\raggedright}{}{0em}{}[\titlerule]
\titlespacing{\section}{0pt}{3pt}{3pt}

\newenvironment{jobshort}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  }
  {
  }

\newenvironment{joblong}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  \begin{minipage}[t]{\linewidth}
  \begin{itemize}[nosep,after=\strut, leftmargin=1em, itemsep=0.5pt,label=\textbullet]
  }
  {
  \end{itemize}
  \end{minipage}
  }

%----------------------------------------------------------------------------------------
% BEGIN DOCUMENT
%----------------------------------------------------------------------------------------
\begin{document}

\pagestyle{empty}

%----------------------------------------------------------------------------------------
%	TITLE
%----------------------------------------------------------------------------------------

% \begin{tabularx}{\linewidth}{ @{}X X@{} }
% \huge{Your Name}\vspace{2pt} & \hfill \emoji{incoming-envelope} email@email.com \\
% \raisebox{-0.05\height}\faGithub\ username \ | \
% \raisebox{-0.00\height}\faLinkedin\ username \ | \ \raisebox{-0.05\height}\faGlobe \ mysite.com  & \hfill \emoji{calling} number
% \end{tabularx}

\begin{tabularx}{\linewidth}{@{} C @{}}
\Huge{Vicky Kumar} \\[7.5pt]
\href{https://github.com/pseudovicky}{\raisebox{-0.05\height}\faGithub\ pseudovicky} \ $|$ \ 
\href{https://linkedin.com/in/pseudovicky}{\raisebox{-0.05\height}\faLinkedin\ pseudovicky} \ $|$ \ 
\href{https://vickykumar.me}{\raisebox{-0.05\height}\faGlobe \ vickykumar.me} \ $|$ \ 
\href{mailto:sudovicky@gmail.com}{\raisebox{-0.05\height}\faEnvelope \ sudovicky@gmail.com} \ $|$ \ 
\href{tel:+917295818429}{\raisebox{-0.05\height}\faMobile \ +91 7295818429} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	SKILLS
%----------------------------------------------------------------------------------------
\section{Skills}
\begin{tabularx}{\linewidth}{@{}l X@{}}

Languages & \normalsize{Python, C/C++, Java, DSA, HTML, CSS, JavaScript, MySQL} \\

Frameworks & \normalsize{React.js, Tailwind CSS, Bootstrap, Node.js, Express.js} \\

Libraries & \normalsize{NumPy, Pandas, Matplotlib, Seaborn, Scikit-learn, Folium, Keras, TensorFlow } \\

Tools / Platforms & \normalsize{MongoDB, MS SQL Server, IBM Cognos, Excel, Selenium, Canva, Figma, Power BI, Cisco Packet Tracer} \\

Soft Skills & \normalsize{Problem-Solving, Teamwork \& Collaboration, Strategic Planning, Flexibility} \\
\end{tabularx}

%----------------------------------------------------------------------------------------
%	Experience
%----------------------------------------------------------------------------------------

\section{Experience}
\begin{joblong}{\textbf{Hariyalikart (Startup)} – Web Developer}{Jan 2024 – Jul 2024}
    \item Built and launched the company’s primary website \href{https://hariyalikart.com/}{hariyalikart.com}, supporting their mission of delivering smart-agriculture IoT and AI solutions to improve water usage and crop health.
    \item Developed full-stack features using the \textbf{MERN stack (MongoDB, Express.js, React.js, Node.js)}, integrating REST APIs and creating a fully responsive, mobile-first user experience.
    \item Collaborated with the tech team to implement feature enhancements, including real-time IoT sensor dashboards and dynamic content modules, improving farmer engagement and platform scalability.
    \item Optimized website performance—reducing load time, improving SEO, and enhancing mobile responsiveness—while ensuring maintainable code structure and effective version control practices.
\end{joblong}


%----------------------------------------------------------------------------------------
%	Research and Publication
%----------------------------------------------------------------------------------------
\section*{Research \& Publications}
\begin{joblong}{\textbf{The Relationship Between Data and Information} — Correlation Analysis, Data Quality, Association Rule Mining}{ Nov 2025}
\item Conducting an IEEE-style research study examining the transformation of raw data into meaningful information through correlation analysis, data integrity evaluation, and statistical sensitivity methods.
\item Centered on \textbf{Association Rule Mining} (Apriori/FP-Growth) to uncover implicit relationships and reveal latent behavioral and operational insights within complex datasets.
\end{joblong}

%----------------------------------------------------------------------------------------
%	Project
%----------------------------------------------------------------------------------------


\section{Projects}

\begin{joblong}{\textbf{Old Car Price Prediction} — Python, Pandas, NumPy, Scikit-learn, AdaBoost, MERN Stack, Web Scraping, Vercel}{Aug 2025}

\item Scraped real-world used car data from Quikr.com and merged it with Kaggle datasets, followed by rigorous cleaning, anomaly detection, and preprocessing to create a high-quality training dataset.
\item Performed feature engineering and removed unnecessary or low-impact columns using \textbf{Adjusted R\textsuperscript{2}} to ensure only meaningful variables contributed to the model’s performance.
\item Built a baseline Linear Regression model, then boosted it with \textbf{AdaBoost}, improving prediction accuracy by nearly \textbf{20\%} and achieving an overall \textbf{R\textsuperscript{2} ≈ 0.92}.
\item Implemented the entire pipeline using Python, Pandas, NumPy, and scikit-learn, including dimensionality reduction, error analysis, and evaluation metrics such as R\textsuperscript{2}, MAE, and RMSE. Deployed the final system through a MERN-based web application hosted on \textbf{Vercel}, enabling users to interactively explore visual analytics (year, mileage, fuel type) and obtain accurate resale price predictions.
\end{joblong}


\begin{joblong}{\textbf{Sorting Algorithm Visualizer} (\href{https://sort-visualiser-chi.vercel.app/}{ Deployed on Vercel })}{May 2025}
\item Developed an interactive web application to visualize multiple sorting algorithms in real time, improving conceptual understanding of algorithmic behavior.
\item Implemented nine sorting algorithms—including Bubble Sort, Quick Sort, Merge Sort, Heap Sort, and Radix Sort—with step-by-step visualization of comparisons, swaps, and intermediate states.
\item Added customizable controls for array size, randomization, and sorting speed (Slow, Medium, Fast), enabling an adaptive and engaging learning experience.
\item Built a client–server architecture using \textbf{Node.js, Express.js, and Socket.IO} to stream algorithm execution steps and rendered progress through an intuitive bar-graph-based UI.
\end{joblong}

\begin{joblong}{\textbf{House Price Prediction} — Python, Pandas, Scikit-learn, Django, Kaggle, MongoDB}{Jan 2025}
\item Collected and integrated housing datasets from Kaggle and other external sources, creating a unified dataset followed by EDA, data cleaning, anomaly detection, duplicate removal, feature engineering, and dimensionality reduction to ensure model robustness.
\item Built and trained a Linear Regression model achieving an \textbf{R\textsuperscript{2} ≈ 0.89}, then improved accuracy using \textbf{AdaBoost}; evaluated performance using R\textsuperscript{2}, RMSE, and MAE for reliable predictions on unseen data.
\item Deployed the complete solution on a Django-based web platform with input forms for property details, integrated visual analytics (historical trends, yearly variations, profit margins), and conducted stochastic error analysis to generate actionable insights for stakeholders.
\end{joblong}

\begin{joblong}{\textbf{Excelify} — MERN Stack, RESTful API, JWT, Multer, SheetJS, Data Processing}{Dec 2024}
\item Developed a full-stack MERN application for automated Excel data processing, enabling secure uploads and efficient server-side handling of large and complex datasets.
\item Built a scalable RESTful API using Node.js and Express, implementing \textbf{JWT-based authentication}, \textbf{Multer} for file management, and \textbf{SheetJS} to parse and store structured Excel data in MongoDB.
\item Created a responsive, high-performance frontend with \textbf{React 19} and \textbf{Tailwind CSS}, featuring a drag-and-drop uploader and real-time data previews to enhance user experience and workflow efficiency.
\end{joblong}

\begin{joblong}{\textbf{CheckInn} — MySQL, Node.js, Express, JavaScript, React \quad
\href{https://github.com/pseudovicky/CheckInn}{GitHub} \;|\;
\href{https://docs.google.com/document/d/13uZuB80_r-V9aIMEZW-nD5cQcaGiPV-5iy5fOFhbq6A/edit?usp=sharing}{Project Report}
}{Aug 2024}
\item Built a full-stack hotel booking and management system using \textbf{MySQL}, Node.js, and JavaScript, designing optimized relational schemas, high-performance SQL queries, and secure booking workflows with responsive UI components.
\item Delivered dynamic stored procedures, triggers, and analytical SQL modules powering real-time operations and reporting.
\end{joblong}

\begin{joblong}{\textbf{Online Weather Application} — Java, AWT, Swing, MySQL (JDBC)}{Oct 2024}
\item Designed and developed an online weather application using Java, AWT, Swing, and MySQL (JDBC) to provide users with real-time weather updates and location-based forecasts.
\item Built an intuitive and responsive user interface using Java Swing, improving navigation, data visualization, and overall user experience.
\item Integrated a MySQL database for efficient storage and retrieval of weather records, ensuring data integrity and optimized query performance for faster response times.
\end{joblong}







%----------------------------------------------------------------------------------------
%	CERTIFICATIONS
%----------------------------------------------------------------------------------------

\section{Certificates}
\begin{jobshort}{\textbf{VLSI Design – MSME Professional Training} (\href{https://inleski.com/certificate.php?certificate=20250619IB7304617369}{INLESKI})}{Jun 2025 -- Jul 2025}
\end{jobshort}
\begin{jobshort}{\textbf{Responsive Web Design} (\href{https://www.freecodecamp.org/certification/fcc47b3390d-0c34-4d57-8948-2eac1209f8ea/responsive-web-design}{freeCodeCamp})}{Jul 2025 -- Sep 2025}
\end{jobshort}
\begin{jobshort}{\textbf{Machine Learning \& Data Visualization} (IBM)}{Oct 2024 -- Jan 2025}
\end{jobshort}
\begin{jobshort}{\textbf{Data Science Masters} (\href{https://pwskills.com/learn/certificate/7cb6d99b-da82-45dd-9784-06513263a44c/}{PW Skills})}{Jan 2024 -- Dec 2024}
\end{jobshort}
\begin{jobshort}{\textbf{MERN Stack Development} (\href{https://mycourse.app/qWomCXFiY9wBahWJA}{Apna College})}{Dec 2022 -- Oct 2023}
\end{jobshort}


%----------------------------------------------------------------------------------------
%	Activities \& Achievements
%----------------------------------------------------------------------------------------


\section{Activities \& Achievements}
\begin{itemize}[leftmargin=1em, itemsep=4pt]

    \item \textbf{Code-A-Haunt Hackathon (Coding Blocks, LPU):} 
    Participated in a high-intensity coding and development sprint focused on rapid problem-solving and teamwork. Built an \textbf{AI Therapist} Application using Python, Django, and Google AI Studio, integrating the trained model into the backend through API-based communication.

    \item \textbf{Responsive CSS Challenge — 21 Days Bootcamp:} 
    Completed 21 mini-projects in 21 days, strengthening expertise in responsive design, media queries, accessibility, and SEO-friendly UI development. Created modern, scalable, and production-ready CSS layouts.

    \item \textbf{AlumniConnect Application (MERN, Socket.io, APIs):} 
    Developed during the Code Strome 36-Hour Hackathon organized by \textbf{Microsoft Learn Student Ambassadors}, where our team was awarded \textbf{Runner-Up}. Designed a real-time mentorship platform enabling students and alumni to connect through live chat, appointment scheduling, and role-based dashboards.

\end{itemize}


%----------------------------------------------------------------------------------------
%	EDUCATION
%----------------------------------------------------------------------------------------


\section{Education}
\begin{tabularx}{\linewidth}{@{} X r @{}}

    \textbf{Lovely Professional University} & Phagwara, Punjab \\
    Master of Computer Application (Hons. in AI/ML), in collaboration with \textbf{IBM}; CGPA: 8.0 & Aug 2024 – Present \\[1.5pt]

    \textbf{Indira Gandhi National Open University} & Patna, Bihar \\
    Bachelor of Computer Application; Percentage: 62\% & Jul 2019 – Dec 2023 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Intermediate (PCM); Percentage: 70\% & Mar 2017 – Mar 2019 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Matriculation; Percentage: 75\% & 2016 – 2017 \\

\end{tabularx}


\end{document}

# %% [markdown]
# Research and Publication

# %%
%----------------------------------------------------------------------------------------
%	Research and Publication
%----------------------------------------------------------------------------------------
\section*{Research \& Publications}
\begin{joblong}{\textbf{The Relationship Between Data and Information}\textbf{-} Correlation, Transformation and Discovery through Data Science}{Nov 2025}
\item Conducting an IEEE-style research study examining the transformation of raw data into meaningful information through correlation analysis, data integrity evaluation, and statistical sensitivity methods.
\item Centered on \textbf{Association Rule Mining} (Apriori/FP-Growth) to uncover implicit relationships and reveal latent behavioral and operational insights within complex datasets.
\end{joblong}

# %%
%----------------------------------------------------------------------------------------
%	Research and Publication
%----------------------------------------------------------------------------------------
\section*{Research \& Publications}
\begin{joblong}{\textbf{The Relationship Between Data and Information} \textbf{-} Correlation, Transformation and Discovery through Data Science}{Nov 2025}
\item Conducting an IEEE-style research study examining how raw data transforms into meaningful information through correlation analysis, data integrity evaluation, and statistical sensitivity methods.
\item Performed structured surveys and examined real-world supermarket datasets to understand how variables interact and produce emerging patterns in customer behavior and product associations.
\item Centered on \textbf{Association Rule Mining} (Apriori/FP-Growth) to identify hidden relationships and uncover latent behavioral and operational insights within complex datasets.
\end{joblong}

# %%
%----------------------------------------------------------------------------------------
%	Research and Publication
%----------------------------------------------------------------------------------------
\section*{Research \& Publications}
\begin{joblong}{\textbf{The Relationship Between Data and Information} \textbf{-} Correlation, Transformation and Discovery through Data Science}{Nov 2025}
\item Examined supermarket datasets and survey responses to study how variable interactions generate meaningful patterns in customer behavior and product associations.
\item Applied \textbf{Association Rule Mining} (Apriori/FP-Growth) to uncover hidden relationships and support the transformation of raw data into actionable information.

\end{joblong}

# %%
%----------------------------------------------------------------------------------------
%	Research and Publication
%----------------------------------------------------------------------------------------
\section*{Research \& Publications}
\begin{joblong}{\textbf{The Relationship Between Data and Information} \textbf{-} Correlation, Transformation and Discovery through Data Science}{Nov 2025}
\item Examined supermarket datasets and survey responses to analyze how raw data transforms into meaningful information through correlation analysis, data integrity checks, and variable-interaction patterns.
\item Applied \textbf{Association Rule Mining} (Apriori/FP-Growth) to uncover hidden relationships and extract latent behavioral and operational insights from complex datasets.
\end{joblong}

# %%
\begin{joblong}{\textbf{Old Car Price Prediction} — Python, Pandas, NumPy, Scikit-learn, AdaBoost, MERN Stack, Web Scraping, Vercel}{Aug 2025}

\item Scraped real-world used car data from Quikr.com and merged it with Kaggle datasets, followed by rigorous cleaning, anomaly detection, and preprocessing to create a high-quality training dataset.
\item Performed feature engineering and removed unnecessary or low-impact columns using \textbf{Adjusted R\textsuperscript{2}} to ensure only meaningful variables contributed to the model’s performance.
\item Built a baseline Linear Regression model, then boosted it with \textbf{AdaBoost}, improving prediction accuracy by nearly \textbf{20\%} and achieving an overall \textbf{R\textsuperscript{2} ≈ 0.92}.
\item Implemented the entire pipeline using Python, Pandas, NumPy, and scikit-learn, including dimensionality reduction, error analysis, and evaluation metrics such as R\textsuperscript{2}, MAE, and RMSE. Deployed the final system through a MERN-based web application hosted on \textbf{Vercel}, enabling users to interactively explore visual analytics (year, mileage, fuel type) and obtain accurate resale price predictions.
\end{joblong}

# %%
\item Scraped real-world used car data from Quikr and Kaggle, performed cleaning, anomaly detection, and feature engineering using Adjusted R\textsuperscript{2} to build a high-quality dataset.
\item Developed a Linear Regression model boosted with \textbf{AdaBoost}, achieving \textbf{R\textsuperscript{2} ≈ 0.92}, and deployed the full ML pipeline as a MERN-based web app on \textbf{Vercel} with interactive price-prediction analytics.

# %%
\documentclass[a4paper,11pt]{article}

%----------------------------------------------------------------------------------------
% PACKAGES
%----------------------------------------------------------------------------------------
\usepackage{url}
\usepackage{parskip}
\setlength{\parskip}{0pt}
\usepackage{color}
\usepackage{graphicx}
\usepackage[usenames,dvipsnames]{xcolor}
\usepackage[scale=0.95, top=1.25cm, bottom=1.25cm]{geometry}
\usepackage{fontspec} % Use fontspec to load system fonts
\setmainfont{EB Garamond} % Set the document font to Garamond
\usepackage{setspace} % Package for line spacing
\setstretch{1.05} % Increase line spacing by 10%
\usepackage{tabularx}
\usepackage{enumitem}
\newcolumntype{C}{>{\centering\arraybackslash}X}
\usepackage{supertabular}
\newlength{\fullcollw}
\setlength{\fullcollw}{0.47\textwidth}
\usepackage{titlesec}
\usepackage{multicol}
\usepackage{multirow}
\usepackage[style=authoryear,sorting=ynt, maxbibnames=2]{biblatex}
\usepackage[unicode, draft=false]{hyperref}
\definecolor{linkcolour}{rgb}{0,0.2,0.6}
\hypersetup{colorlinks,breaklinks,urlcolor=linkcolour,linkcolor=linkcolour}
\setlength\bibitemsep{1em}
\usepackage{fontawesome5}

%----------------------------------------------------------------------------------------
% CV LAYOUT
%----------------------------------------------------------------------------------------
\titleformat{\section}{\large\scshape\raggedright}{}{0em}{}[\titlerule]
\titlespacing{\section}{0pt}{3pt}{3pt}

\newenvironment{jobshort}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  }
  {
  }

\newenvironment{joblong}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  \begin{minipage}[t]{\linewidth}
  \begin{itemize}[nosep,after=\strut, leftmargin=1em, itemsep=0.5pt,label=\textbullet]
  }
  {
  \end{itemize}
  \end{minipage}
  }

%----------------------------------------------------------------------------------------
% BEGIN DOCUMENT
%----------------------------------------------------------------------------------------
\begin{document}

\pagestyle{empty}

%----------------------------------------------------------------------------------------
%	TITLE
%----------------------------------------------------------------------------------------

% \begin{tabularx}{\linewidth}{ @{}X X@{} }
% \huge{Your Name}\vspace{2pt} & \hfill \emoji{incoming-envelope} email@email.com \\
% \raisebox{-0.05\height}\faGithub\ username \ | \
% \raisebox{-0.00\height}\faLinkedin\ username \ | \ \raisebox{-0.05\height}\faGlobe \ mysite.com  & \hfill \emoji{calling} number
% \end{tabularx}

\begin{tabularx}{\linewidth}{@{} C @{}}
\Huge{Vicky Kumar} \\[7.5pt]
\href{https://github.com/pseudovicky}{\raisebox{-0.05\height}\faGithub\ pseudovicky} \ $|$ \ 
\href{https://linkedin.com/in/pseudovicky}{\raisebox{-0.05\height}\faLinkedin\ pseudovicky} \ $|$ \ 
\href{https://vickykumar.me}{\raisebox{-0.05\height}\faGlobe \ vickykumar.me} \ $|$ \ 
\href{mailto:sudovicky@gmail.com}{\raisebox{-0.05\height}\faEnvelope \ sudovicky@gmail.com} \ $|$ \ 
\href{tel:+917295818429}{\raisebox{-0.05\height}\faMobile \ +91 7295818429} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	SKILLS
%----------------------------------------------------------------------------------------
\section{Skills}
\begin{tabularx}{\linewidth}{@{}l X@{}}

Languages & \normalsize{Python, C/C++, Java, DSA, HTML, CSS, JavaScript, MySQL, ML, DL, NLP, Neural Networks, MLDLC } \\

Frameworks & \normalsize{React.js, Tailwind CSS, Bootstrap, Node.js, Express.js} \\

Libraries & \normalsize{NumPy, Pandas, Matplotlib, Seaborn, Scikit-learn, Folium, Keras, TensorFlow, NLTK, Plotly, OpenCV } \\

Tools / Platforms & \normalsize{MongoDB, MS SQL Server, IBM Cognos, IBM Cloud, Excel, Selenium, Canva, Figma, Power BI, Cisco Packet Tracer} \\

Soft Skills & \normalsize{Problem-Solving, Teamwork, Strategic Planning, Technical Writing, Information Synthesis, Attention to Detail} \\
\end{tabularx}

%----------------------------------------------------------------------------------------
%	Experience
%----------------------------------------------------------------------------------------

\section{Experience}
\begin{joblong}{\textbf{Hariyalikart (Startup)} – Web Developer}{Jan 2024 – Jul 2024}
    \item Built and launched the company’s primary website \href{https://hariyalikart.com/}{hariyalikart.com}, supporting their mission of delivering smart-agriculture IoT and AI solutions to improve water usage and crop health.
    \item Developed full-stack features using the \textbf{MERN stack (MongoDB, Express.js, React.js, Node.js)}, integrating REST APIs and creating a fully responsive, mobile-first user experience.
    \item Collaborated with the tech team to implement feature enhancements, including real-time IoT sensor dashboards and dynamic content modules, improving farmer engagement and platform scalability.
    \item Optimized website performance—reducing load time, improving SEO, and enhancing mobile responsiveness—while ensuring maintainable code structure and effective version control practices.
\end{joblong}


%----------------------------------------------------------------------------------------
%	Research and Publication
%----------------------------------------------------------------------------------------
\section*{Research \& Publications}
\begin{joblong}{\textbf{The Relationship Between Data and Information} \textbf{-} Correlation, Transformation and Discovery through Data Science}{Nov 2025}
\item Examined supermarket datasets and survey responses to analyze how raw data transforms into meaningful information through correlation analysis, data integrity checks, and variable-interaction patterns.
\item Applied \textbf{Association Rule Mining} (Apriori/FP-Growth) to uncover hidden relationships and extract latent behavioral and operational insights from complex datasets.
\end{joblong}


%----------------------------------------------------------------------------------------
%	Project
%----------------------------------------------------------------------------------------

\section{Projects}
%	Project 1 
\begin{joblong}{\textbf{Old Car Price Prediction} — Python, Pandas, NumPy, Scikit-learn, AdaBoost, MERN Stack, Web Scraping, Vercel}{Aug 2025}
\item Scraped real world car data from Quikr and Kaggle, performed cleaning, anomaly detection, and feature engineering using Adjusted R\textsuperscript{2}.
\item Built a Linear Regression model boosted with \textbf{AdaBoost}, improving accuracy and achieving an overall \textbf{R\textsuperscript{2} ≈ 0.92} with detailed error analysis. 
\item Deployed the complete ML pipeline as a MERN-based web app on \textbf{Vercel}, offering interactive visual analytics and accurate price predictions.
\end{joblong}

%	Project 2
\begin{joblong}{\textbf{Sorting Algorithm Visualizer} (\href{https://sort-visualiser-chi.vercel.app/}{ Deployed on Vercel })}{May 2025}
\item Developed an interactive web application to visualize multiple sorting algorithms in real time, improving conceptual understanding of algorithmic behavior.
\item Implemented nine sorting algorithms—including Bubble Sort, Quick Sort, Merge Sort, Heap Sort, and Radix Sort—with step-by-step visualization of comparisons, swaps, and intermediate states.
\item Added customizable controls for array size, randomization, and sorting speed (Slow, Medium, Fast), enabling an adaptive and engaging learning experience.
\item Built a client–server architecture using \textbf{Node.js, Express.js, and Socket.IO} to stream algorithm execution steps and rendered progress through an intuitive bar-graph-based UI.
\end{joblong}

%	Project 3
\begin{joblong}{\textbf{House Price Prediction} — Python, Pandas, Scikit-learn, Django, Kaggle, MongoDB}{Jan 2025}
\item Collected and integrated housing datasets from Kaggle and other external sources, creating a unified dataset followed by EDA, data cleaning, anomaly detection, duplicate removal, feature engineering, and dimensionality reduction to ensure model robustness.
\item Built and trained a Linear Regression model achieving an \textbf{R\textsuperscript{2} ≈ 0.89}, then improved accuracy using \textbf{AdaBoost}; evaluated performance using R\textsuperscript{2}, RMSE, and MAE for reliable predictions on unseen data.
\item Deployed the complete solution on a Django-based web platform with input forms for property details, integrated visual analytics (historical trends, yearly variations, profit margins), and conducted stochastic error analysis to generate actionable insights for stakeholders.
\end{joblong}

\begin{joblong}{\textbf{Excelify} — MERN Stack, RESTful API, JWT, Multer, SheetJS, Data Processing}{Dec 2024}
\item Developed a full-stack MERN application for automated Excel data processing, enabling secure uploads and efficient server-side handling of large and complex datasets.
\item Built a scalable RESTful API using Node.js and Express, implementing \textbf{JWT-based authentication}, \textbf{Multer} for file management, and \textbf{SheetJS} to parse and store structured Excel data in MongoDB.
\item Created a responsive, high-performance frontend with \textbf{React 19} and \textbf{Tailwind CSS}, featuring a drag-and-drop uploader and real-time data previews to enhance user experience and workflow efficiency.
\end{joblong}

\begin{joblong}{\textbf{CheckInn} — MySQL, Node.js, Express, JavaScript, React \quad
\href{https://github.com/pseudovicky/CheckInn}{GitHub} \;|\;
\href{https://docs.google.com/document/d/13uZuB80_r-V9aIMEZW-nD5cQcaGiPV-5iy5fOFhbq6A/edit?usp=sharing}{Project Report}
}{Aug 2024}
\item Built a full-stack hotel booking and management system using \textbf{MySQL}, Node.js, and JavaScript, designing optimized relational schemas, high-performance SQL queries, and secure booking workflows with responsive UI components.
\item Delivered dynamic stored procedures, triggers, and analytical SQL modules powering real-time operations and reporting.
\end{joblong}

\begin{joblong}{\textbf{Online Weather Application} — Java, AWT, Swing, MySQL (JDBC)}{Oct 2024}
\item Designed and developed an online weather application using Java, AWT, Swing, and MySQL (JDBC) to provide users with real-time weather updates and location-based forecasts.
\item Built an intuitive and responsive user interface using Java Swing, improving navigation, data visualization, and overall user experience.
\item Integrated a MySQL database for efficient storage and retrieval of weather records, ensuring data integrity and optimized query performance for faster response times.
\end{joblong}







%----------------------------------------------------------------------------------------
%	CERTIFICATIONS
%----------------------------------------------------------------------------------------

\section{Certificates}
\begin{jobshort}{\textbf{VLSI Design – MSME Professional Training} (\href{https://inleski.com/certificate.php?certificate=20250619IB7304617369}{INLESKI})}{Jun 2025 -- Jul 2025}
\end{jobshort}
\begin{jobshort}{\textbf{Responsive Web Design} (\href{https://www.freecodecamp.org/certification/fcc47b3390d-0c34-4d57-8948-2eac1209f8ea/responsive-web-design}{freeCodeCamp})}{Jul 2025 -- Sep 2025}
\end{jobshort}
\begin{jobshort}{\textbf{Machine Learning \& Data Visualization} (IBM)}{Oct 2024 -- Jan 2025}
\end{jobshort}
\begin{jobshort}{\textbf{Data Science Masters} (\href{https://pwskills.com/learn/certificate/7cb6d99b-da82-45dd-9784-06513263a44c/}{PW Skills})}{Jan 2024 -- Dec 2024}
\end{jobshort}
\begin{jobshort}{\textbf{MERN Stack Development} (\href{https://mycourse.app/qWomCXFiY9wBahWJA}{Apna College})}{Dec 2022 -- Oct 2023}
\end{jobshort}


%----------------------------------------------------------------------------------------
%	Activities \& Achievements
%----------------------------------------------------------------------------------------


\section{Activities \& Achievements}
\begin{itemize}[leftmargin=1em, itemsep=4pt]

    \item \textbf{Code-A-Haunt Hackathon (Coding Blocks, LPU):} 
    Participated in a high-intensity coding and development sprint focused on rapid problem-solving and teamwork. Built an \textbf{AI Therapist} Application using Python, Django, and Google AI Studio, integrating the trained model into the backend through API-based communication.

    \item \textbf{Responsive CSS Challenge — 21 Days Bootcamp:} 
    Completed 21 mini-projects in 21 days, strengthening expertise in responsive design, media queries, accessibility, and SEO-friendly UI development. Created modern, scalable, and production-ready CSS layouts.

    \item \textbf{AlumniConnect Application (MERN, Socket.io, APIs):} 
    Developed during the Code Strome 36-Hour Hackathon organized by \textbf{Microsoft Learn Student Ambassadors}, where our team was awarded \textbf{Runner-Up}. Designed a real-time mentorship platform enabling students and alumni to connect through live chat, appointment scheduling, and role-based dashboards.

\end{itemize}


%----------------------------------------------------------------------------------------
%	EDUCATION
%----------------------------------------------------------------------------------------


\section{Education}
\begin{tabularx}{\linewidth}{@{} X r @{}}

    \textbf{Lovely Professional University} & Phagwara, Punjab \\
    Master of Computer Application (Hons. in AI/ML), in collaboration with \textbf{IBM}; CGPA: 8.0 & Aug 2024 – Present \\[1.5pt]

    \textbf{Indira Gandhi National Open University} & Patna, Bihar \\
    Bachelor of Computer Application; Percentage: 62\% & Jul 2019 – Dec 2023 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Intermediate (PCM); Percentage: 70\% & Mar 2017 – Mar 2019 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Matriculation; Percentage: 75\% & 2016 – 2017 \\

\end{tabularx}


\end{document}
