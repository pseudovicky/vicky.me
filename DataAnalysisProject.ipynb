# %%
\begin{joblong}{\textbf{Panic Buying Analysis During COVID-19} — Data Analysis, Google Mobility, Apple Mobility}{2024}
\item Used Google and Apple mobility datasets to track shifts in shopping activity during the first COVID-19 wave and detect signs of panic buying across multiple countries.
\item Cleaned data, visualized trends, and compared regional behavior to understand how lockdown announcements and movement restrictions influenced consumer stockpiling patterns.
\end{joblong}

# %%
\begin{joblong}{\textbf{Behavioral Analysis of Panic Buying During Early COVID-19 Using Mobility Data} — Python, Pandas, NumPy, Data Visualization}{2024}
\item Leveraged Google and Apple Mobility datasets to quantify changes in essential shopping activity during early COVID-19 and identify panic-driven stockpiling behavior across countries.
\item Conducted EDA and time-based trend analysis to link mobility surges with lockdown announcements, revealing how communication timing influenced consumer behavior and retail supply stress.
\end{joblong}

# %%
\begin{joblong}{\textbf{Pandemic-Driven Consumer Behavior Analysis} — Python, Pandas, NumPy, Data Visualization}{2024}
\item Leveraged Google and Apple Mobility datasets to quantify changes in grocery and pharmacy visits during the first COVID-19 wave, identifying panic-driven stockpiling behavior across regions.
\item Conducted EDA and time-based trend analysis to connect mobility surges with government lockdown announcements, highlighting how communication timing influenced consumer reactions and supply-chain stress.
\end{joblong}

# %%
\begin{joblong}{\textbf{COVID-19 Panic Buying Analysis} — Python, Pandas, NumPy, Data Visualization}{2024}
\item Leveraged Google and Apple Mobility datasets to quantify changes in grocery and pharmacy visits during the first COVID-19 wave, identifying panic-driven stockpiling behavior across regions.
\item Conducted EDA and time-based trend analysis to connect mobility surges with government lockdown announcements, highlighting how communication timing influenced consumer reactions and supply-chain stress.
\end{joblong}

# %%
\begin{joblong}{\textbf{COVID-19 Panic Buying Analysis} — Python, Pandas, NumPy, Data Visualization}{2024}
\item Leveraged Google and Apple Mobility datasets to quantify changes in grocery and pharmacy visits during the first COVID-19 wave, identifying panic-driven stockpiling behavior across regions.
\item Conducted EDA and time-based trend analysis to connect mobility surges with government lockdown announcements, highlighting how communication timing influenced consumer reactions and supply-chain stress.
\end{joblong}
