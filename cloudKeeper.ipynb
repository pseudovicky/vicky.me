# %%
\begin{joblong}{\textbf{Old Car Price Prediction} — Python, Pandas, NumPy, Scikit-learn, AdaBoost, MERN Stack, Web Scraping, Vercel}{Aug 2025}

\item Scraped real-world used car data from Quikr.com and merged it with Kaggle datasets, followed by rigorous cleaning, anomaly detection, and preprocessing to create a high-quality training dataset.
\item Performed feature engineering and removed unnecessary or low-impact columns using \textbf{Adjusted R\textsuperscript{2}} to ensure only meaningful variables contributed to the model’s performance.
\item Built a baseline Linear Regression model, then boosted it with \textbf{AdaBoost}, improving prediction accuracy by nearly \textbf{20\%} and achieving an overall \textbf{R\textsuperscript{2} ≈ 0.92}.
\item Implemented the entire pipeline using Python, Pandas, NumPy, and scikit-learn, including dimensionality reduction, error analysis, and evaluation metrics such as R\textsuperscript{2}, MAE, and RMSE. Deployed the final system through a MERN-based web application hosted on \textbf{Vercel}, enabling users to interactively explore visual analytics (year, mileage, fuel type) and obtain accurate resale price predictions.
\end{joblong}

# %%
\begin{joblong}{\textbf{Association Rule Mining for Retail Optimization} — Python, MLxtend, IBM Watson Studio, IBM Cloud}{Mar 2025}
\item Built a market basket analysis system using \textbf{Apriori} and \textbf{FP-Growth} algorithms to find which products are frequently bought together.
\item Used \textbf{support, confidence, and lift} to create useful recommendations for product placement and combo offers in supermarkets.
\item Deployed the solution on \textbf{IBM Cloud} with Watson Studio for easy access and real-time insights to help improve sales decisions.
\end{joblong}

# %%
\begin{joblong}{\textbf{Behavioral Analysis of Panic Buying During Early COVID-19 Using Mobility Data} — Python, Pandas, NumPy, Data Visualization}{2024}
\item Leveraged Google and Apple Mobility datasets to quantify changes in essential shopping activity during early COVID-19 and identify panic-driven stockpiling behavior across countries.
\item Conducted EDA and time-based trend analysis to link mobility surges with lockdown announcements, revealing how communication timing influenced consumer behavior and retail supply stress.
\end{joblong}

# %%
\documentclass[a4paper,11pt]{article}

%----------------------------------------------------------------------------------------
% PACKAGES
%----------------------------------------------------------------------------------------
\usepackage{url}
\usepackage{parskip}
\setlength{\parskip}{0pt}
\usepackage{color}
\usepackage{graphicx}
\usepackage[usenames,dvipsnames]{xcolor}
\usepackage[scale=0.95, top=1.25cm, bottom=1.25cm]{geometry}
\usepackage{fontspec} % Use fontspec to load system fonts
\setmainfont{EB Garamond} % Set the document font to Garamond
\usepackage{setspace} % Package for line spacing
\setstretch{1.05} % Increase line spacing by 10%
\usepackage{tabularx}
\usepackage{enumitem}
\newcolumntype{C}{>{\centering\arraybackslash}X}
\usepackage{supertabular}
\newlength{\fullcollw}
\setlength{\fullcollw}{0.47\textwidth}
\usepackage{titlesec}
\usepackage{multicol}
\usepackage{multirow}
\usepackage[style=authoryear,sorting=ynt, maxbibnames=2]{biblatex}
\usepackage[unicode, draft=false]{hyperref}
\definecolor{linkcolour}{rgb}{0,0.2,0.6}
\hypersetup{colorlinks,breaklinks,urlcolor=linkcolour,linkcolor=linkcolour}
\setlength\bibitemsep{1em}
\usepackage{fontawesome5}

%----------------------------------------------------------------------------------------
% CV LAYOUT
%----------------------------------------------------------------------------------------
\titleformat{\section}{\large\scshape\raggedright}{}{0em}{}[\titlerule]
\titlespacing{\section}{0pt}{3pt}{3pt}

\newenvironment{jobshort}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  }
  {
  }

\newenvironment{joblong}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  \begin{minipage}[t]{\linewidth}
  \begin{itemize}[nosep,after=\strut, leftmargin=1em, itemsep=0.5pt,label=\textbullet]
  }
  {
  \end{itemize}
  \end{minipage}
  }

%----------------------------------------------------------------------------------------
% BEGIN DOCUMENT
%----------------------------------------------------------------------------------------
\begin{document}

\pagestyle{empty}

%----------------------------------------------------------------------------------------
%	TITLE
%----------------------------------------------------------------------------------------

% \begin{tabularx}{\linewidth}{ @{}X X@{} }
% \huge{Your Name}\vspace{2pt} & \hfill \emoji{incoming-envelope} email@email.com \\
% \raisebox{-0.05\height}\faGithub\ username \ | \
% \raisebox{-0.00\height}\faLinkedin\ username \ | \ \raisebox{-0.05\height}\faGlobe \ mysite.com  & \hfill \emoji{calling} number
% \end{tabularx}

\begin{tabularx}{\linewidth}{@{} C @{}}
\Huge{Vicky Kumar} \\[7.5pt]
\href{https://github.com/pseudovicky}{\raisebox{-0.05\height}\faGithub\ pseudovicky} \ $|$ \ 
\href{https://linkedin.com/in/pseudovicky}{\raisebox{-0.05\height}\faLinkedin\ pseudovicky} \ $|$ \ 
\href{https://vickykumar.me}{\raisebox{-0.05\height}\faGlobe \ vickykumar.me} \ $|$ \ 
\href{mailto:sudovicky@gmail.com}{\raisebox{-0.05\height}\faEnvelope \ sudovicky@gmail.com} \ $|$ \ 
\href{tel:+917295818429}{\raisebox{-0.05\height}\faMobile \ +91 7295818429} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	SKILLS
%----------------------------------------------------------------------------------------
\section{Skills}
\begin{tabularx}{\linewidth}{@{}l X@{}}

Languages & \normalsize{Python, C/C++, Java, DSA, HTML, CSS, JavaScript, MySQL, ML, DL, NLP, Neural Networks, MLDLC } \\

Frameworks & \normalsize{React.js, Tailwind CSS, Bootstrap, Node.js, Express.js} \\

Libraries & \normalsize{NumPy, Pandas, Matplotlib, Seaborn, Scikit-learn, Folium, Keras, TensorFlow, NLTK, Plotly, OpenCV } \\

Tools / Platforms & \normalsize{MongoDB, MS SQL Server, IBM Cognos, IBM Cloud, Excel, Selenium, Canva, Figma, Power BI, Cisco Packet Tracer} \\

Soft Skills & \normalsize{Problem-Solving, Teamwork, Strategic Planning, Technical Writing, Information Synthesis, Attention to Detail} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	Project
%----------------------------------------------------------------------------------------

\section{Projects}
%	Project 1 
\begin{joblong}{\textbf{Old Car Price Prediction} — Python, Pandas, NumPy, Scikit-learn, AdaBoost, Web Scraping}{Aug '25}
\item Scraped real world car data from Quikr and Kaggle, performed cleaning, anomaly detection, and feature engineering using Adjusted R\textsuperscript{2}.
\item Built a Linear Regression model boosted with \textbf{AdaBoost}, improving accuracy and achieving an overall \textbf{R\textsuperscript{2} ≈ 0.92} with detailed error analysis. 
\end{joblong}


\begin{joblong}{\textbf{Association Rule Mining for Retail Optimization} — Python, MLxtend, IBM Watson Studio, IBM Cloud}{Mar '25}
\item Built a market basket analysis system using \textbf{Apriori} and \textbf{FP-Growth} algorithms to find which products are frequently bought together.
\item Used \textbf{support, confidence, and lift} to create useful recommendations for product placement and combo offers in supermarkets.
\item Deployed the solution on \textbf{IBM Cloud} with Watson Studio for easy access and real-time insights to help improve sales decisions.
\end{joblong}


\begin{joblong}{\textbf{Panic Buying Analysis During Early COVID-19} — Data Analysis, Google Mobility, Apple Mobility}{Aug '24}
\item Analyzed Google and Apple mobility datasets to track changes in essential shopping activity during the first COVID-19 wave and identify panic-buying behavior across regions.
\item Cleaned and visualized mobility trends to evaluate how lockdown announcements and movement restrictions influenced consumer stockpiling patterns.
\end{joblong}


%----------------------------------------------------------------------------------------
%	CERTIFICATIONS
%----------------------------------------------------------------------------------------

\section{Certificates}
\begin{jobshort}{\textbf{VLSI Design – MSME Professional Training} (\href{https://inleski.com/certificate.php?certificate=20250619IB7304617369}{INLESKI})}{Jun '25 -- Jul '25}
\end{jobshort}
\begin{jobshort}{\textbf{Responsive Web Design} (\href{https://www.freecodecamp.org/certification/fcc47b3390d-0c34-4d57-8948-2eac1209f8ea/responsive-web-design}{freeCodeCamp})}{Jul '25 -- Sep '25}
\end{jobshort}
\begin{jobshort}{\textbf{Machine Learning \& Data Visualization} (IBM)}{Oct '24 -- Jan '25}
\end{jobshort}
\begin{jobshort}{\textbf{Data Science Masters} (\href{https://pwskills.com/learn/certificate/7cb6d99b-da82-45dd-9784-06513263a44c/}{PW Skills})}{Jan '24 -- Dec '24}
\end{jobshort}
\begin{jobshort}{\textbf{MERN Stack Development} (\href{https://mycourse.app/qWomCXFiY9wBahWJA}{Apna College})}{Dec '22 -- Oct '23}
\end{jobshort}


%----------------------------------------------------------------------------------------
%	Activities \& Achievements
%----------------------------------------------------------------------------------------


\section{Activities \& Achievements}
\begin{itemize}[leftmargin=1em, itemsep=4pt]

    \item \textbf{Code-A-Haunt Hackathon (Coding Blocks, LPU):} 
    Participated in a high-intensity coding and development sprint focused on rapid problem-solving and teamwork. Built an \textbf{AI Therapist} Application using Python, Django, and Google AI Studio, integrating the trained model into the backend through API-based communication.

    \item \textbf{Responsive CSS Challenge — 21 Days Bootcamp:} 
    Completed 21 mini-projects in 21 days, strengthening expertise in responsive design, media queries, accessibility, and SEO-friendly UI development. Created modern, scalable, and production-ready CSS layouts.

    \item \textbf{AlumniConnect Application (MERN, Socket.io, APIs):} 
    Developed during the Code Strome 36-Hour Hackathon organized by \textbf{Microsoft Learn Student Ambassadors}, where our team was awarded \textbf{Runner-Up}. Designed a real-time mentorship platform enabling students and alumni to connect through live chat, appointment scheduling, and role-based dashboards.

\end{itemize}

%----------------------------------------------------------------------------------------
%	EDUCATION
%----------------------------------------------------------------------------------------

\section{Education}
\begin{tabularx}{\linewidth}{@{} X r @{}}

    \textbf{Lovely Professional University} & Phagwara, Punjab \\
    Master of Computer Application (Hons. in AI/ML), in collaboration with \textbf{IBM}; CGPA: 8.0 & Aug '24 – Present \\[1.5pt]

    \textbf{Indira Gandhi National Open University} & Patna, Bihar \\
    Bachelor of Computer Application; Percentage: 62\% & Jul '19 – Dec '23 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Intermediate (PCM); Percentage: 70\% & Mar '17 – Mar '19 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Matriculation; Percentage: 75\% & Mar '16 – Feb '17 \\

\end{tabularx}

\end{document}

# %%
\documentclass[a4paper,11pt]{article}

%----------------------------------------------------------------------------------------
% PACKAGES
%----------------------------------------------------------------------------------------
\usepackage{url}
\usepackage{parskip}
\setlength{\parskip}{0pt}
\usepackage{color}
\usepackage{graphicx}
\usepackage[usenames,dvipsnames]{xcolor}
\usepackage[scale=0.95, top=1.25cm, bottom=1.25cm]{geometry}
\usepackage{fontspec} % Use fontspec to load system fonts
\setmainfont{EB Garamond} % Set the document font to Garamond
\usepackage{setspace} % Package for line spacing
\setstretch{1.05} % Increase line spacing by 10%
\usepackage{tabularx}
\usepackage{enumitem}
\newcolumntype{C}{>{\centering\arraybackslash}X}
\usepackage{supertabular}
\newlength{\fullcollw}
\setlength{\fullcollw}{0.47\textwidth}
\usepackage{titlesec}
\usepackage{multicol}
\usepackage{multirow}
\usepackage[style=authoryear,sorting=ynt, maxbibnames=2]{biblatex}
\usepackage[unicode, draft=false]{hyperref}
\definecolor{linkcolour}{rgb}{0,0.2,0.6}
\hypersetup{colorlinks,breaklinks,urlcolor=linkcolour,linkcolor=linkcolour}
\setlength\bibitemsep{1em}
\usepackage{fontawesome5}

%----------------------------------------------------------------------------------------
% CV LAYOUT
%----------------------------------------------------------------------------------------
\titleformat{\section}{\large\scshape\raggedright}{}{0em}{}[\titlerule]
\titlespacing{\section}{0pt}{3pt}{3pt}

\newenvironment{jobshort}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  }
  {
  }

\newenvironment{joblong}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  \begin{minipage}[t]{\linewidth}
  \begin{itemize}[nosep,after=\strut, leftmargin=1em, itemsep=0.5pt,label=\textbullet]
  }
  {
  \end{itemize}
  \end{minipage}
  }

%----------------------------------------------------------------------------------------
% BEGIN DOCUMENT
%----------------------------------------------------------------------------------------
\begin{document}

\pagestyle{empty}

%----------------------------------------------------------------------------------------
%	TITLE
%----------------------------------------------------------------------------------------

% \begin{tabularx}{\linewidth}{ @{}X X@{} }
% \huge{Your Name}\vspace{2pt} & \hfill \emoji{incoming-envelope} email@email.com \\
% \raisebox{-0.05\height}\faGithub\ username \ | \
% \raisebox{-0.00\height}\faLinkedin\ username \ | \ \raisebox{-0.05\height}\faGlobe \ mysite.com  & \hfill \emoji{calling} number
% \end{tabularx}

\begin{tabularx}{\linewidth}{@{} C @{}}
\Huge{Vicky Kumar} \\[7.5pt]
\href{https://github.com/pseudovicky}{\raisebox{-0.05\height}\faGithub\ pseudovicky} \ $|$ \ 
\href{https://linkedin.com/in/pseudovicky}{\raisebox{-0.05\height}\faLinkedin\ pseudovicky} \ $|$ \ 
\href{https://vickykumar.me}{\raisebox{-0.05\height}\faGlobe \ vickykumar.me} \ $|$ \ 
\href{mailto:sudovicky@gmail.com}{\raisebox{-0.05\height}\faEnvelope \ sudovicky@gmail.com} \ $|$ \ 
\href{tel:+917295818429}{\raisebox{-0.05\height}\faMobile \ +91 7295818429} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	SKILLS
%----------------------------------------------------------------------------------------
\section{Skills}
\begin{tabularx}{\linewidth}{@{}l X@{}}

Languages & \normalsize{Python, C/C++, Java, DSA, HTML, CSS, JavaScript, MySQL, ML, DL, NLP, Neural Networks, MLDLC } \\

Frameworks & \normalsize{React.js, Tailwind CSS, Bootstrap, Node.js, Express.js} \\

Libraries & \normalsize{NumPy, Pandas, Matplotlib, Seaborn, Scikit-learn, Folium, Keras, TensorFlow, NLTK, Plotly, OpenCV } \\

Tools / Platforms & \normalsize{MongoDB, MS SQL Server, IBM Cognos, IBM Cloud, Excel, Selenium, Canva, Figma, Power BI, Cisco Packet Tracer} \\

Soft Skills & \normalsize{Problem-Solving, Teamwork, Strategic Planning, Technical Writing, Information Synthesis, Attention to Detail} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	Project
%----------------------------------------------------------------------------------------

\section{Projects}
%	Project 1 
\begin{joblong}{\textbf{Old Car Price Prediction} — Python, Pandas, NumPy, Scikit-learn, AdaBoost, Web Scraping}{Aug '25}
\item Scraped real world car data from Quikr and Kaggle, performed cleaning, anomaly detection, and feature engineering using Adjusted R\textsuperscript{2}.
\item Built a Linear Regression model boosted with \textbf{AdaBoost}, improving accuracy and achieving an overall \textbf{R\textsuperscript{2} ≈ 0.92} with detailed error analysis. 
\end{joblong}


\begin{joblong}{\textbf{Association Rule Mining for Retail Optimization} — Python, MLxtend, IBM Watson Studio, IBM Cloud}{Mar '25}
\item Built a market basket analysis system using \textbf{Apriori} and \textbf{FP-Growth} algorithms to find which products are frequently bought together.
\item Used \textbf{support, confidence, and lift} to create useful recommendations for product placement and combo offers in supermarkets.
\item Deployed the solution on \textbf{IBM Cloud} with Watson Studio for easy access and real-time insights to help improve sales decisions.
\end{joblong}


\begin{joblong}{\textbf{Panic Buying Analysis During Early COVID-19} — Data Analysis, Google Mobility, Apple Mobility}{Aug '24}
\item Analyzed Google and Apple mobility datasets to track changes in essential shopping activity during the first COVID-19 wave and identify panic-buying behavior across regions.
\item Cleaned and visualized mobility trends to evaluate how lockdown announcements and movement restrictions influenced consumer stockpiling patterns.
\end{joblong}


%----------------------------------------------------------------------------------------
%	CERTIFICATIONS
%----------------------------------------------------------------------------------------

\section{Certificates}
\begin{jobshort}{\textbf{VLSI Design – MSME Professional Training} (\href{https://inleski.com/certificate.php?certificate=20250619IB7304617369}{INLESKI})}{Jun '25 -- Jul '25}
\end{jobshort}
\begin{jobshort}{\textbf{Responsive Web Design} (\href{https://www.freecodecamp.org/certification/fcc47b3390d-0c34-4d57-8948-2eac1209f8ea/responsive-web-design}{freeCodeCamp})}{Jul '25 -- Sep '25}
\end{jobshort}
\begin{jobshort}{\textbf{Machine Learning \& Data Visualization} (IBM)}{Oct '24 -- Jan '25}
\end{jobshort}
\begin{jobshort}{\textbf{Data Science Masters} (\href{https://pwskills.com/learn/certificate/7cb6d99b-da82-45dd-9784-06513263a44c/}{PW Skills})}{Jan '24 -- Dec '24}
\end{jobshort}
\begin{jobshort}{\textbf{MERN Stack Development} (\href{https://mycourse.app/qWomCXFiY9wBahWJA}{Apna College})}{Dec '22 -- Oct '23}
\end{jobshort}


%----------------------------------------------------------------------------------------
%	Activities \& Achievements
%----------------------------------------------------------------------------------------


\section{Activities \& Achievements}
\begin{itemize}[leftmargin=1em, itemsep=4pt]

    \item \textbf{Code-A-Haunt Hackathon (Coding Blocks, LPU):} 
    Participated in a high-intensity coding and development sprint focused on rapid problem-solving and teamwork. Built an \textbf{AI Therapist} Application using Python, Django, and Google AI Studio, integrating the trained model into the backend through API-based communication.

    \item \textbf{Responsive CSS Challenge — 21 Days Bootcamp:} 
    Completed 21 mini-projects in 21 days, strengthening expertise in responsive design, media queries, accessibility, and SEO-friendly UI development. Created modern, scalable, and production-ready CSS layouts.

    \item \textbf{AlumniConnect Application (MERN, Socket.io, APIs):} 
    Developed during the Code Strome 36-Hour Hackathon organized by \textbf{Microsoft Learn Student Ambassadors}, where our team was awarded \textbf{Runner-Up}. Designed a real-time mentorship platform enabling students and alumni to connect through live chat, appointment scheduling, and role-based dashboards.

\end{itemize}

%----------------------------------------------------------------------------------------
%	EDUCATION
%----------------------------------------------------------------------------------------

\section{Education}
\begin{tabularx}{\linewidth}{@{} X r @{}}

    \textbf{Lovely Professional University} & Phagwara, Punjab \\
    Master of Computer Application (Hons. in AI/ML), in collaboration with \textbf{IBM}; CGPA: 8.0 & Aug '24 – Present \\[1.5pt]

    \textbf{Indira Gandhi National Open University} & Patna, Bihar \\
    Bachelor of Computer Application; Percentage: 62\% & Jul '19 – Dec '23 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Intermediate (PCM); Percentage: 70\% & Mar '17 – Mar '19 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Matriculation; Percentage: 75\% & Mar '16 – Feb '17 \\

\end{tabularx}

\end{document}

# %%
\documentclass[a4paper,11pt]{article}

%----------------------------------------------------------------------------------------
% PACKAGES
%----------------------------------------------------------------------------------------
\usepackage{url}
\usepackage{parskip}
\setlength{\parskip}{0pt}
\usepackage{color}
\usepackage{graphicx}
\usepackage[usenames,dvipsnames]{xcolor}
\usepackage[scale=0.95, top=1.25cm, bottom=1.25cm]{geometry}
\usepackage{fontspec} % Use fontspec to load system fonts
\setmainfont{EB Garamond} % Set the document font to Garamond
\usepackage{setspace} % Package for line spacing
\setstretch{1.05} % Increase line spacing by 10%
\usepackage{tabularx}
\usepackage{enumitem}
\newcolumntype{C}{>{\centering\arraybackslash}X}
\usepackage{supertabular}
\newlength{\fullcollw}
\setlength{\fullcollw}{0.47\textwidth}
\usepackage{titlesec}
\usepackage{multicol}
\usepackage{multirow}
\usepackage[style=authoryear,sorting=ynt, maxbibnames=2]{biblatex}
\usepackage[unicode, draft=false]{hyperref}
\definecolor{linkcolour}{rgb}{0,0.2,0.6}
\hypersetup{colorlinks,breaklinks,urlcolor=linkcolour,linkcolor=linkcolour}
\setlength\bibitemsep{1em}
\usepackage{fontawesome5}

%----------------------------------------------------------------------------------------
% CV LAYOUT
%----------------------------------------------------------------------------------------
\titleformat{\section}{\large\scshape\raggedright}{}{0em}{}[\titlerule]
\titlespacing{\section}{0pt}{3pt}{3pt}

\newenvironment{jobshort}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  }
  {
  }

\newenvironment{joblong}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  \begin{minipage}[t]{\linewidth}
  \begin{itemize}[nosep,after=\strut, leftmargin=1em, itemsep=0.5pt,label=\textbullet]
  }
  {
  \end{itemize}
  \end{minipage}
  }

%----------------------------------------------------------------------------------------
% BEGIN DOCUMENT
%----------------------------------------------------------------------------------------
\begin{document}

\pagestyle{empty}

%----------------------------------------------------------------------------------------
%	TITLE
%----------------------------------------------------------------------------------------

% \begin{tabularx}{\linewidth}{ @{}X X@{} }
% \huge{Your Name}\vspace{2pt} & \hfill \emoji{incoming-envelope} email@email.com \\
% \raisebox{-0.05\height}\faGithub\ username \ | \
% \raisebox{-0.00\height}\faLinkedin\ username \ | \ \raisebox{-0.05\height}\faGlobe \ mysite.com  & \hfill \emoji{calling} number
% \end{tabularx}

\begin{tabularx}{\linewidth}{@{} C @{}}
\Huge{Vicky Kumar} \\[7.5pt]
\href{https://github.com/pseudovicky}{\raisebox{-0.05\height}\faGithub\ pseudovicky} \ $|$ \ 
\href{https://linkedin.com/in/pseudovicky}{\raisebox{-0.05\height}\faLinkedin\ pseudovicky} \ $|$ \ 
\href{https://vickykumar.me}{\raisebox{-0.05\height}\faGlobe \ vickykumar.me} \ $|$ \ 
\href{mailto:sudovicky@gmail.com}{\raisebox{-0.05\height}\faEnvelope \ sudovicky@gmail.com} \ $|$ \ 
\href{tel:+917295818429}{\raisebox{-0.05\height}\faMobile \ +91 7295818429} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	SKILLS
%----------------------------------------------------------------------------------------
\section{Skills}
\begin{tabularx}{\linewidth}{@{}l X@{}}

Languages & \normalsize{Python, C/C++, Java, DSA, HTML, CSS, JavaScript, MySQL } \\

Frameworks & \normalsize{React.js, Tailwind CSS, Bootstrap, Node.js, Express.js} \\

Libraries & \normalsize{NumPy, Pandas, Matplotlib, Seaborn, Scikit-learn, Folium, Keras, TensorFlow, NLTK, Plotly, OpenCV } \\

Tools / Platforms & \normalsize{MongoDB, MS SQL Server, IBM Cognos, IBM Cloud, Excel, Selenium, Canva, Figma, Power BI, Cisco Packet Tracer} \\

Soft Skills & \normalsize{Problem-Solving, Teamwork, Strategic Planning, Technical Writing, Information Synthesis, Attention to Detail} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	Project
%----------------------------------------------------------------------------------------

\section{Projects}

%	Project 1 
\begin{joblong}{\textbf{Old Car Price Prediction} — Python, Scikit-learn, Machine Learning ,AdaBoost, Web Scraping}{Aug '25}
\item Collected car pricing data from Quikr and Kaggle, cleaned anomalies, engineered impactful features.
\item Trained Linear Regression optimized with AdaBoost, achieving strong performance (\textbf{R\textsuperscript{2} ≈ 0.92}) on predictions.
\item Delivered accurate resale estimates with evaluation metrics ensuring reliable insights for end users.
\end{joblong}


%	Project 2
\begin{joblong}{\textbf{Association Rule Mining for Retail Optimization} — Python, MLxtend, IBM Watson Studio, IBM Cloud}{Mar '25}
\item Implemented Apriori and FP-Growth models uncovering product association patterns boosting profitable retail combinations.
\item Applied support, confidence, lift metrics generating actionable cross-sell recommendations improving customer purchase experience.
\item Automated rule mining workflow enabling scalable analytics and faster decision-making for retail product strategy.
\item Deployed solution on IBM Cloud using Watson Studio delivering real-time insights enhancing supermarket sales.
\end{joblong}


%	Project 3
\begin{joblong}{\textbf{Panic Buying Analysis During Early COVID-19} — Data Analysis, Google Mobility, Apple Mobility}{Aug '24}
\item Analyzed COVID-19 mobility datasets identifying panic-driven shopping behavior affecting essential goods demand globally.
\item Cleaned and visualized trends revealing lockdown announcements strongly influencing sudden retail stockpiling surges.
\item Compared multiple regions showing varied pandemic responses shaping consumer movements and purchase patterns.
\item Extracted insights helping decision-makers improve supply chain planning during emergency shopping spikes.
\end{joblong}

%----------------------------------------------------------------------------------------
%	CERTIFICATIONS
%----------------------------------------------------------------------------------------

\section{Certificates}
\begin{jobshort}{\textbf{VLSI Design – MSME Professional Training} (\href{https://inleski.com/certificate.php?certificate=20250619IB7304617369}{INLESKI})}{Jun '25 -- Jul '25}
\end{jobshort}
\begin{jobshort}{\textbf{Responsive Web Design} (\href{https://www.freecodecamp.org/certification/fcc47b3390d-0c34-4d57-8948-2eac1209f8ea/responsive-web-design}{freeCodeCamp})}{Jul '25 -- Sep '25}
\end{jobshort}
\begin{jobshort}{\textbf{Machine Learning \& Data Visualization} (IBM)}{Oct '24 -- Jan '25}
\end{jobshort}
\begin{jobshort}{\textbf{Data Science Masters} (\href{https://pwskills.com/learn/certificate/7cb6d99b-da82-45dd-9784-06513263a44c/}{PW Skills})}{Jan '24 -- Dec '24}
\end{jobshort}
\begin{jobshort}{\textbf{MERN Stack Development} (\href{https://mycourse.app/qWomCXFiY9wBahWJA}{Apna College})}{Dec '22 -- Oct '23}
\end{jobshort}


%----------------------------------------------------------------------------------------
%	Activities \& Achievements
%----------------------------------------------------------------------------------------


\section{Activities \& Achievements}
\begin{itemize}[leftmargin=1em, itemsep=4pt]

    \item \textbf{Code-A-Haunt Hackathon (Coding Blocks, LPU):} 
    Participated in a high-intensity coding and development sprint focused on rapid problem-solving and teamwork. Built an \textbf{AI Therapist} Application using Python, Django, and Google AI Studio, integrating the trained model into the backend through API-based communication.

    \item \textbf{Responsive CSS Challenge — 21 Days Bootcamp:} 
    Completed 21 mini-projects in 21 days, strengthening expertise in responsive design, media queries, accessibility, and SEO-friendly UI development. Created modern, scalable, and production-ready CSS layouts.

    \item \textbf{AlumniConnect Application (MERN, Socket.io, APIs):} 
    Developed during the Code Strome 36-Hour Hackathon organized by \textbf{Microsoft Learn Student Ambassadors}, where our team was awarded \textbf{Runner-Up}. Designed a real-time mentorship platform enabling students and alumni to connect through live chat, appointment scheduling, and role-based dashboards.

\end{itemize}

%----------------------------------------------------------------------------------------
%	EDUCATION
%----------------------------------------------------------------------------------------

\section{Education}
\begin{tabularx}{\linewidth}{@{} X r @{}}

    \textbf{Lovely Professional University} & Phagwara, Punjab \\
    Master of Computer Application (Hons. in AI/ML), in collaboration with \textbf{IBM}; CGPA: 8.0 & Aug '24 – Present \\[1.5pt]

    \textbf{Indira Gandhi National Open University} & Patna, Bihar \\
    Bachelor of Computer Application; Percentage: 62\% & Jul '19 – Dec '23 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Intermediate (PCM); Percentage: 70\% & Mar '17 – Mar '19 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Matriculation; Percentage: 75\% & Mar '16 – Feb '17 \\

\end{tabularx}

\end{document}

# %%
\documentclass[a4paper,11pt]{article}

%----------------------------------------------------------------------------------------
% PACKAGES
%----------------------------------------------------------------------------------------
\usepackage{url}
\usepackage{parskip}
\setlength{\parskip}{0pt}
\usepackage{color}
\usepackage{graphicx}
\usepackage[usenames,dvipsnames]{xcolor}
\usepackage[scale=0.95, top=1.25cm, bottom=1.25cm]{geometry}
\usepackage{fontspec} % Use fontspec to load system fonts
\setmainfont{EB Garamond} % Set the document font to Garamond
\usepackage{setspace} % Package for line spacing
\setstretch{1.05} % Increase line spacing by 10%
\usepackage{tabularx}
\usepackage{enumitem}
\newcolumntype{C}{>{\centering\arraybackslash}X}
\usepackage{supertabular}
\newlength{\fullcollw}
\setlength{\fullcollw}{0.47\textwidth}
\usepackage{titlesec}
\usepackage{multicol}
\usepackage{multirow}
\usepackage[style=authoryear,sorting=ynt, maxbibnames=2]{biblatex}
\usepackage[unicode, draft=false]{hyperref}
\definecolor{linkcolour}{rgb}{0,0.2,0.6}
\hypersetup{colorlinks,breaklinks,urlcolor=linkcolour,linkcolor=linkcolour}
\setlength\bibitemsep{1em}
\usepackage{fontawesome5}

%----------------------------------------------------------------------------------------
% CV LAYOUT
%----------------------------------------------------------------------------------------
\titleformat{\section}{\large\scshape\raggedright}{}{0em}{}[\titlerule]
\titlespacing{\section}{0pt}{3pt}{3pt}

\newenvironment{jobshort}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  }
  {
  }

\newenvironment{joblong}[2]
  {
  \begin{tabularx}{\linewidth}{@{}l X r@{}}
  #1 & \hfill & #2 \\[1.5pt]
  \end{tabularx}
  \begin{minipage}[t]{\linewidth}
  \begin{itemize}[nosep,after=\strut, leftmargin=1em, itemsep=0.5pt,label=\textbullet]
  }
  {
  \end{itemize}
  \end{minipage}
  }

%----------------------------------------------------------------------------------------
% BEGIN DOCUMENT
%----------------------------------------------------------------------------------------
\begin{document}

\pagestyle{empty}

%----------------------------------------------------------------------------------------
%	TITLE
%----------------------------------------------------------------------------------------

% \begin{tabularx}{\linewidth}{ @{}X X@{} }
% \huge{Your Name}\vspace{2pt} & \hfill \emoji{incoming-envelope} email@email.com \\
% \raisebox{-0.05\height}\faGithub\ username \ | \
% \raisebox{-0.00\height}\faLinkedin\ username \ | \ \raisebox{-0.05\height}\faGlobe \ mysite.com  & \hfill \emoji{calling} number
% \end{tabularx}

\begin{tabularx}{\linewidth}{@{} C @{}}
\Huge{Vicky Kumar} \\[7.5pt]
\href{https://github.com/pseudovicky}{\raisebox{-0.05\height}\faGithub\ pseudovicky} \ $|$ \ 
\href{https://linkedin.com/in/pseudovicky}{\raisebox{-0.05\height}\faLinkedin\ pseudovicky} \ $|$ \ 
\href{https://vickykumar.me}{\raisebox{-0.05\height}\faGlobe \ vickykumar.me} \ $|$ \ 
\href{mailto:sudovicky@gmail.com}{\raisebox{-0.05\height}\faEnvelope \ sudovicky@gmail.com} \ $|$ \ 
\href{tel:+917295818429}{\raisebox{-0.05\height}\faMobile \ +91 7295818429} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	SKILLS
%----------------------------------------------------------------------------------------
\section{Skills}
\begin{tabularx}{\linewidth}{@{}l X@{}}

Languages & \normalsize{Python, C/C++, Java, DSA, HTML, CSS, JavaScript, MySQL } \\

Frameworks & \normalsize{React.js, Tailwind CSS, Bootstrap, Node.js, Express.js} \\

Libraries & \normalsize{NumPy, Pandas, Matplotlib, Seaborn, Scikit-learn, Folium, Keras, TensorFlow, OpenCV } \\

Tools / Platforms & \normalsize{MongoDB, MS SQL Server, IBM Cognos, IBM Cloud, Excel, Selenium, Figma, Power BI } \\

Soft Skills & \normalsize{Problem-Solving, Teamwork, Strategic Planning, Technical Writing, Information Synthesis, Attention to Detail} \\
\end{tabularx}


%----------------------------------------------------------------------------------------
%	Project
%----------------------------------------------------------------------------------------

\section{Projects}

%	Project 1 
\begin{joblong}{\textbf{Old Car Price Prediction} — Python, Scikit-learn, Machine Learning ,AdaBoost, Web Scraping}{Aug '25}
\item Collected car pricing data from Quikr and Kaggle, cleaned anomalies, engineered impactful features.
\item Trained Linear Regression optimized with AdaBoost, achieving strong performance (\textbf{R\textsuperscript{2} ≈ 0.92}) on predictions.
\item Delivered accurate resale estimates with evaluation metrics ensuring reliable insights for end users.
\end{joblong}


%	Project 2
\begin{joblong}{\textbf{Association Rule Mining for Retail Optimization} — Python, MLxtend, IBM Watson Studio, IBM Cloud}{Mar '25}
\item Implemented Apriori and FP-Growth models uncovering product association patterns boosting profitable retail combinations.
\item Applied support, confidence, lift metrics generating actionable cross-sell recommendations improving customer purchase experience.
\item Automated rule mining workflow enabling scalable analytics and faster decision-making for retail product strategy.
\item Deployed solution on IBM Cloud using Watson Studio delivering real-time insights enhancing supermarket sales.
\end{joblong}


%	Project 3
\begin{joblong}{\textbf{Panic Buying Analysis During Early COVID-19} — Data Analysis, Google Mobility, Apple Mobility}{Aug '24}
\item Analyzed COVID-19 mobility datasets identifying panic-driven shopping behavior affecting essential goods demand globally.
\item Cleaned and visualized trends revealing lockdown announcements strongly influencing sudden retail stockpiling surges.
\item Compared multiple regions showing varied pandemic responses shaping consumer movements and purchase patterns.
\item Extracted insights helping decision-makers improve supply chain planning during emergency shopping spikes.
\end{joblong}

%----------------------------------------------------------------------------------------
%	CERTIFICATIONS
%----------------------------------------------------------------------------------------

\section{Certificates}
\begin{jobshort}{\textbf{VLSI Design – MSME Professional Training} (\href{https://inleski.com/certificate.php?certificate=20250619IB7304617369}{INLESKI})}{Jun '25 -- Jul '25}
\end{jobshort}
\begin{jobshort}{\textbf{Responsive Web Design} (\href{https://www.freecodecamp.org/certification/fcc47b3390d-0c34-4d57-8948-2eac1209f8ea/responsive-web-design}{freeCodeCamp})}{Jul '25 -- Sep '25}
\end{jobshort}
\begin{jobshort}{\textbf{Machine Learning \& Data Visualization} (IBM)}{Oct '24 -- Jan '25}
\end{jobshort}
\begin{jobshort}{\textbf{Data Science Masters} (\href{https://pwskills.com/learn/certificate/7cb6d99b-da82-45dd-9784-06513263a44c/}{PW Skills})}{Jan '24 -- Dec '24}
\end{jobshort}
\begin{jobshort}{\textbf{MERN Stack Development} (\href{https://mycourse.app/qWomCXFiY9wBahWJA}{Apna College})}{Dec '22 -- Oct '23}
\end{jobshort}


%----------------------------------------------------------------------------------------
%	Activities \& Achievements
%----------------------------------------------------------------------------------------


\section{Activities \& Achievements}
\begin{itemize}[leftmargin=1em, itemsep=4pt]

    \item \textbf{Code-A-Haunt Hackathon (Coding Blocks, LPU):} 
    Participated in a high-intensity coding and development sprint focused on rapid problem-solving and teamwork. Built an \textbf{AI Therapist} Application using Python, Django, and Google AI Studio, integrating the trained model into the backend through API-based communication.

    \item \textbf{Responsive CSS Challenge — 21 Days Bootcamp:} 
    Completed 21 mini-projects in 21 days, strengthening expertise in responsive design, media queries, accessibility, and SEO-friendly UI development. Created modern, scalable, and production-ready CSS layouts.

    \item \textbf{AlumniConnect Application (MERN, Socket.io, APIs):} 
    Developed during the Code Strome 36-Hour Hackathon organized by \textbf{Microsoft Learn Student Ambassadors}, where our team was awarded \textbf{Runner-Up}. Designed a real-time mentorship platform enabling students and alumni to connect through live chat, appointment scheduling, and role-based dashboards.

\end{itemize}

%----------------------------------------------------------------------------------------
%	EDUCATION
%----------------------------------------------------------------------------------------

\section{Education}
\begin{tabularx}{\linewidth}{@{} X r @{}}

    \textbf{Lovely Professional University} & Phagwara, Punjab \\
    Master of Computer Application (Hons. in AI/ML), in collaboration with \textbf{IBM}; CGPA: 8.0 & Aug '24 – Present \\[1.5pt]

    \textbf{Indira Gandhi National Open University} & Patna, Bihar \\
    Bachelor of Computer Application; Percentage: 62\% & Jul '19 – Dec '23 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Intermediate (PCM); Percentage: 70\% & Mar '17 – Mar '19 \\[1.5pt]

    \textbf{BSEB Board} & Patna, Bihar \\
    Matriculation; Percentage: 75\% & Mar '16 – Feb '17 \\

\end{tabularx}

\end{document}
